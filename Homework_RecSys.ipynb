# %% [markdown]
# # Content Based Filtering
#
# * **Used Dataset :** https://www.kaggle.com/rounakbanik/the-movies-dataset/data
# * **Latest MovieLens Dataset :** https://grouplens.org/datasets/movielens/latest/

# %% [markdown]
# **Files :**
#   * _movies_metadata_ : Features belong to movies (~45k)
#   * _keywords_ : Keywords extracted from plot of the movie
#   * _credits_ : Cast and crew information
#   * _links_ : TMDB and IMDB IDs of all movies
#   * _ratings_ : User-Movie interactions

# %%
from IPython.display import display, HTML

def show_as_html(doc):
    display(HTML(doc.to_html()))

# %%
# %%capture
# !pip3 install spacy
# !python3 -m spacy download en_core_web_sm

# %%
import spacy
import pandas as pd
from numpy import dot
from numpy.linalg import norm
import numpy as np
from tqdm.notebook import tqdm
from scipy.spatial import distance

# %%
metadata = pd.read_csv('/home/gsoykan20/Desktop/inzva/week2/Recommender Systems/MovieLens/movies_metadata.csv', low_memory=False)
metadata['overview'] = metadata['overview'].fillna('')

# %%
show_as_html(metadata.head())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>adult</th>
#       <th>belongs_to_collection</th>
#       <th>budget</th>
#       <th>genres</th>
#       <th>homepage</th>
#       <th>id</th>
#       <th>imdb_id</th>
#       <th>original_language</th>
#       <th>original_title</th>
#       <th>overview</th>
#       <th>popularity</th>
#       <th>poster_path</th>
#       <th>production_companies</th>
#       <th>production_countries</th>
#       <th>release_date</th>
#       <th>revenue</th>
#       <th>runtime</th>
#       <th>spoken_languages</th>
#       <th>status</th>
#       <th>tagline</th>
#       <th>title</th>
#       <th>video</th>
#       <th>vote_average</th>
#       <th>vote_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>False</td>
#       <td>{'id': 10194, 'name': 'Toy Story Collection', 'poster_path': '/7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg', 'backdrop_path': '/9FBwqcd9IRruEDUrTdcaafOMKUq.jpg'}</td>
#       <td>30000000</td>
#       <td>[{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': 10751, 'name': 'Family'}]</td>
#       <td>http://toystory.disney.com/toy-story</td>
#       <td>862</td>
#       <td>tt0114709</td>
#       <td>en</td>
#       <td>Toy Story</td>
#       <td>Led by Woody, Andy's toys live happily in his room until Andy's birthday brings Buzz Lightyear onto the scene. Afraid of losing his place in Andy's heart, Woody plots against Buzz. But when circumstances separate Buzz and Woody from their owner, the duo eventually learns to put aside their differences.</td>
#       <td>21.946943</td>
#       <td>/rhIRbceoE9lR4veEXuwCC2wARtG.jpg</td>
#       <td>[{'name': 'Pixar Animation Studios', 'id': 3}]</td>
#       <td>[{'iso_3166_1': 'US', 'name': 'United States of America'}]</td>
#       <td>1995-10-30</td>
#       <td>373554033.0</td>
#       <td>81.0</td>
#       <td>[{'iso_639_1': 'en', 'name': 'English'}]</td>
#       <td>Released</td>
#       <td>NaN</td>
#       <td>Toy Story</td>
#       <td>False</td>
#       <td>7.7</td>
#       <td>5415.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>False</td>
#       <td>NaN</td>
#       <td>65000000</td>
#       <td>[{'id': 12, 'name': 'Adventure'}, {'id': 14, 'name': 'Fantasy'}, {'id': 10751, 'name': 'Family'}]</td>
#       <td>NaN</td>
#       <td>8844</td>
#       <td>tt0113497</td>
#       <td>en</td>
#       <td>Jumanji</td>
#       <td>When siblings Judy and Peter discover an enchanted board game that opens the door to a magical world, they unwittingly invite Alan -- an adult who's been trapped inside the game for 26 years -- into their living room. Alan's only hope for freedom is to finish the game, which proves risky as all three find themselves running from giant rhinoceroses, evil monkeys and other terrifying creatures.</td>
#       <td>17.015539</td>
#       <td>/vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg</td>
#       <td>[{'name': 'TriStar Pictures', 'id': 559}, {'name': 'Teitler Film', 'id': 2550}, {'name': 'Interscope Communications', 'id': 10201}]</td>
#       <td>[{'iso_3166_1': 'US', 'name': 'United States of America'}]</td>
#       <td>1995-12-15</td>
#       <td>262797249.0</td>
#       <td>104.0</td>
#       <td>[{'iso_639_1': 'en', 'name': 'English'}, {'iso_639_1': 'fr', 'name': 'Français'}]</td>
#       <td>Released</td>
#       <td>Roll the dice and unleash the excitement!</td>
#       <td>Jumanji</td>
#       <td>False</td>
#       <td>6.9</td>
#       <td>2413.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>False</td>
#       <td>{'id': 119050, 'name': 'Grumpy Old Men Collection', 'poster_path': '/nLvUdqgPgm3F85NMCii9gVFUcet.jpg', 'backdrop_path': '/hypTnLot2z8wpFS7qwsQHW1uV8u.jpg'}</td>
#       <td>0</td>
#       <td>[{'id': 10749, 'name': 'Romance'}, {'id': 35, 'name': 'Comedy'}]</td>
#       <td>NaN</td>
#       <td>15602</td>
#       <td>tt0113228</td>
#       <td>en</td>
#       <td>Grumpier Old Men</td>
#       <td>A family wedding reignites the ancient feud between next-door neighbors and fishing buddies John and Max. Meanwhile, a sultry Italian divorcée opens a restaurant at the local bait shop, alarming the locals who worry she'll scare the fish away. But she's less interested in seafood than she is in cooking up a hot time with Max.</td>
#       <td>11.7129</td>
#       <td>/6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg</td>
#       <td>[{'name': 'Warner Bros.', 'id': 6194}, {'name': 'Lancaster Gate', 'id': 19464}]</td>
#       <td>[{'iso_3166_1': 'US', 'name': 'United States of America'}]</td>
#       <td>1995-12-22</td>
#       <td>0.0</td>
#       <td>101.0</td>
#       <td>[{'iso_639_1': 'en', 'name': 'English'}]</td>
#       <td>Released</td>
#       <td>Still Yelling. Still Fighting. Still Ready for Love.</td>
#       <td>Grumpier Old Men</td>
#       <td>False</td>
#       <td>6.5</td>
#       <td>92.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>False</td>
#       <td>NaN</td>
#       <td>16000000</td>
#       <td>[{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}]</td>
#       <td>NaN</td>
#       <td>31357</td>
#       <td>tt0114885</td>
#       <td>en</td>
#       <td>Waiting to Exhale</td>
#       <td>Cheated on, mistreated and stepped on, the women are holding their breath, waiting for the elusive "good man" to break a string of less-than-stellar lovers. Friends and confidants Vannah, Bernie, Glo and Robin talk it all out, determined to find a better way to breathe.</td>
#       <td>3.859495</td>
#       <td>/16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg</td>
#       <td>[{'name': 'Twentieth Century Fox Film Corporation', 'id': 306}]</td>
#       <td>[{'iso_3166_1': 'US', 'name': 'United States of America'}]</td>
#       <td>1995-12-22</td>
#       <td>81452156.0</td>
#       <td>127.0</td>
#       <td>[{'iso_639_1': 'en', 'name': 'English'}]</td>
#       <td>Released</td>
#       <td>Friends are the people who let you be yourself... and never let you forget it.</td>
#       <td>Waiting to Exhale</td>
#       <td>False</td>
#       <td>6.1</td>
#       <td>34.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>False</td>
#       <td>{'id': 96871, 'name': 'Father of the Bride Collection', 'poster_path': '/nts4iOmNnq7GNicycMJ9pSAn204.jpg', 'backdrop_path': '/7qwE57OVZmMJChBpLEbJEmzUydk.jpg'}</td>
#       <td>0</td>
#       <td>[{'id': 35, 'name': 'Comedy'}]</td>
#       <td>NaN</td>
#       <td>11862</td>
#       <td>tt0113041</td>
#       <td>en</td>
#       <td>Father of the Bride Part II</td>
#       <td>Just when George Banks has recovered from his daughter's wedding, he receives the news that she's pregnant ... and that George's wife, Nina, is expecting too. He was planning on selling their home, but that's a plan that -- like George -- will have to change with the arrival of both a grandchild and a kid of his own.</td>
#       <td>8.387519</td>
#       <td>/e64sOI48hQXyru7naBFyssKFxVd.jpg</td>
#       <td>[{'name': 'Sandollar Productions', 'id': 5842}, {'name': 'Touchstone Pictures', 'id': 9195}]</td>
#       <td>[{'iso_3166_1': 'US', 'name': 'United States of America'}]</td>
#       <td>1995-02-10</td>
#       <td>76578911.0</td>
#       <td>106.0</td>
#       <td>[{'iso_639_1': 'en', 'name': 'English'}]</td>
#       <td>Released</td>
#       <td>Just When His World Is Back To Normal... He's In For The Surprise Of His Life!</td>
#       <td>Father of the Bride Part II</td>
#       <td>False</td>
#       <td>5.7</td>
#       <td>173.0</td>
#     </tr>
#   </tbody>
# </table>

# %%
pd.DataFrame(metadata[['original_title','overview']].head())
# Out:
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview
# 0  Led by Woody, Andy's toys live happily in his ...
# 1  When siblings Judy and Peter discover an encha...
# 2  A family wedding reignites the ancient feud be...
# 3  Cheated on, mistreated and stepped on, the wom...
# 4  Just when George Banks has recovered from his ...

# %%
movie_docs = pd.DataFrame(metadata[['original_title','overview']])

# %% [markdown]
# **distance sources:**
# - https://www.sequentix.de/gelquest/help/distance_measures.htm
# - https://en.wikipedia.org/wiki/Chebyshev_distance

# %%
def get_recommendations(title,
                        recommend_k,
                        df,
                        distance_metric='cosine'):
  vector = df[df["original_title"] == title]["overview vectors"].iloc[0]
  shape = vector.shape[0]
  print("vector shape:" + str(shape))
  list_of_vecs = df["overview vectors"].tolist()

  similarities = []
  for b in list_of_vecs:
    try:
      dist = None
      if distance_metric == "cosine":
        #cos_sim = dot(a, b)/(norm(a)*norm(b))
        dist = np.dot(vector, b) / (np.linalg.norm(vector) * np.linalg.norm(b))
      elif distance_metric == "euclidian":
        dist = distance.euclidean(vector, b)
      elif distance_metric == "dice":
        dist = distance.dice(vector, b)
      elif distance_metric == "hamming":
        dist = distance.hamming(vector, b)
      elif distance_metric == "sokalmichener":
        dist = distance.sokalmichener(vector, b)
      elif distance_metric == "sqeuclidean":
        dist = distance.sqeuclidean(vector, b)
      elif distance_metric == "chebyshev":
        dist = distance.chebyshev(vector, b)
      similarities.append(dist)
    except:
      print("exception in similarity metric")
      pass
  indices = np.array(similarities).argsort()[1:recommend_k+1][::-1]

  return [df.iloc[index, 0] for index in indices]

# %% [markdown]
# ## Step 0 (Baseline): Use Overview and extract movie feature vector with spacy

# %%
nlp = spacy.load('en_core_web_sm')

# %%
movie_docs_vectors = []

for idx, row in tqdm(metadata.iterrows(), total=len(metadata)):
  doc = nlp(row["overview"])
  movie_docs_vectors.append(doc.vector)

movie_docs["overview vectors"] = movie_docs_vectors
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=45466.0), HTML(value='')))

# %%
with open('./movie_lens_overview_word_vecs.npy', 'wb') as f:
    np.save(f, np.array(movie_docs['overview vectors']), allow_pickle=True)

# %%
with open('./movie_lens_overview_word_vecs.npy', 'rb') as f:
    word_vecs = np.load(f, allow_pickle=True)

# %%
movie_docs["overview vectors"] = word_vecs
movie_docs.head()
# Out:
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  \
# 0  Led by Woody, Andy's toys live happily in his ...
# 1  When siblings Judy and Peter discover an encha...
# 2  A family wedding reignites the ancient feud be...
# 3  Cheated on, mistreated and stepped on, the wom...
# 4  Just when George Banks has recovered from his ...
#
#                                     overview vectors
# 0  [0.5870929, 0.022778913, -0.108451754, -0.2917...
# 1  [0.31707045, 0.1843554, -0.0031469888, -0.2288...
# 2  [0.5276116, -0.01129298, -0.110098004, -0.0950...
# 3  [-0.0035403734, 0.08286476, -0.11184327, -0.27...
# 4  [0.33208913, -0.13714488, -0.0551012, -0.15579...

# %%
get_recommendations("The Departed", 5, movie_docs)
# Out:
# vector shape:96
# ['Pioneer Woman',
#  '티끌모아 로맨스',
#  'Under the Boardwalk: The Monopoly Story',
#  'Gli occhi freddi della paura',
#  'Los cronocrímenes']

# %%
get_recommendations("Toy Story", 5, movie_docs)
# Out:
# vector shape:96
# ['Gli occhi freddi della paura',
#  '티끌모아 로맨스',
#  'Under the Boardwalk: The Monopoly Story',
#  'Pioneer Woman',
#  'Los cronocrímenes']

# %% [markdown]
# ## Step 1: Use Overview and extract movie feature vector from DistilBertForSequenceClassification
# **source:** https://jalammar.github.io/a-visual-guide-to-using-bert-for-the-first-time/

# %%
from transformers import DistilBertTokenizer, DistilBertModel
import torch

# %%
distilbert_tokenizer = DistilBertTokenizer.from_pretrained('distilbert-base-uncased')
distilbert_model = model = DistilBertModel.from_pretrained('distilbert-base-uncased')
distilbert_model.cuda()
# Out:
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertModel: ['vocab_projector.bias', 'vocab_transform.weight', 'vocab_layer_norm.weight', 'vocab_transform.bias', 'vocab_projector.weight', 'vocab_layer_norm.bias']
# - This IS expected if you are initializing DistilBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# DistilBertModel(
#   (embeddings): Embeddings(
#     (word_embeddings): Embedding(30522, 768, padding_idx=0)
#     (position_embeddings): Embedding(512, 768)
#     (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (transformer): Transformer(
#     (layer): ModuleList(
#       (0): TransformerBlock(
#         (attention): MultiHeadSelfAttention(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (q_lin): Linear(in_features=768, out_features=768, bias=True)
#           (k_lin): Linear(in_features=768, out_features=768, bias=True)
#           (v_lin): Linear(in_features=768, out_features=768, bias=True)
#           (out_lin): Linear(in_features=768, out_features=768, bias=True)
#         )
#         (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (ffn): FFN(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (lin1): Linear(in_features=768, out_features=3072, bias=True)
#           (lin2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#         (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       )
#       (1): TransformerBlock(
#         (attention): MultiHeadSelfAttention(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (q_lin): Linear(in_features=768, out_features=768, bias=True)
#           (k_lin): Linear(in_features=768, out_features=768, bias=True)
#           (v_lin): Linear(in_features=768, out_features=768, bias=True)
#           (out_lin): Linear(in_features=768, out_features=768, bias=True)
#         )
#         (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (ffn): FFN(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (lin1): Linear(in_features=768, out_features=3072, bias=True)
#           (lin2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#         (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       )
#       (2): TransformerBlock(
#         (attention): MultiHeadSelfAttention(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (q_lin): Linear(in_features=768, out_features=768, bias=True)
#           (k_lin): Linear(in_features=768, out_features=768, bias=True)
#           (v_lin): Linear(in_features=768, out_features=768, bias=True)
#           (out_lin): Linear(in_features=768, out_features=768, bias=True)
#         )
#         (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (ffn): FFN(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (lin1): Linear(in_features=768, out_features=3072, bias=True)
#           (lin2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#         (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       )
#       (3): TransformerBlock(
#         (attention): MultiHeadSelfAttention(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (q_lin): Linear(in_features=768, out_features=768, bias=True)
#           (k_lin): Linear(in_features=768, out_features=768, bias=True)
#           (v_lin): Linear(in_features=768, out_features=768, bias=True)
#           (out_lin): Linear(in_features=768, out_features=768, bias=True)
#         )
#         (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (ffn): FFN(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (lin1): Linear(in_features=768, out_features=3072, bias=True)
#           (lin2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#         (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       )
#       (4): TransformerBlock(
#         (attention): MultiHeadSelfAttention(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (q_lin): Linear(in_features=768, out_features=768, bias=True)
#           (k_lin): Linear(in_features=768, out_features=768, bias=True)
#           (v_lin): Linear(in_features=768, out_features=768, bias=True)
#           (out_lin): Linear(in_features=768, out_features=768, bias=True)
#         )
#         (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (ffn): FFN(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (lin1): Linear(in_features=768, out_features=3072, bias=True)
#           (lin2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#         (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       )
#       (5): TransformerBlock(
#         (attention): MultiHeadSelfAttention(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (q_lin): Linear(in_features=768, out_features=768, bias=True)
#           (k_lin): Linear(in_features=768, out_features=768, bias=True)
#           (v_lin): Linear(in_features=768, out_features=768, bias=True)
#           (out_lin): Linear(in_features=768, out_features=768, bias=True)
#         )
#         (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (ffn): FFN(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (lin1): Linear(in_features=768, out_features=3072, bias=True)
#           (lin2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#         (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       )
#     )
#   )
# )

# %%
def generate_movie_docs_vectors_from_distilbert(save_name="movie_lens_overview_distilbert_vecs.npy"):
  movie_docs_vectors = []
  for idx, row in tqdm(metadata.iterrows(), total=len(metadata)):
    overview =  ' '.join(row["overview"].split()[:512])
    token_inputs = distilbert_tokenizer(overview, return_tensors="pt", max_length=512).to('cuda')
    cls_feature_vec = distilbert_model(**token_inputs).last_hidden_state[0, 0].cpu().detach().numpy()
    movie_docs_vectors.append(cls_feature_vec)

  with open('./' + save_name, 'wb') as f:
    np.save(f, np.array(movie_docs_vectors), allow_pickle=True)

# %%
with open('./movie_lens_overview_distilbert_vecs.npy', 'rb') as f:
    word_vecs = np.load(f, allow_pickle=True)

# %%
generate_movie_docs_vectors_from_distilbert()
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=45466.0), HTML(value='')))
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/envs/pytorch/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'overview vectors'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/envs/pytorch/lib/python3.8/site-packages/pandas/core/generic.py in _set_item(self, key, value)
#    3573         try:
# -> 3574             loc = self._info_axis.get_loc(key)
#    3575         except KeyError:
#
# /opt/anaconda3/envs/pytorch/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#
# KeyError: 'overview vectors'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-af98d5214acb> in <module>
# ----> 1 generate_movie_docs_vectors_from_distilbert()
#       2
#
# <ipython-input-8-bedcdf974c7b> in generate_movie_docs_vectors_from_distilbert()
#      13     word_vecs = np.load(f, allow_pickle=True)
#      14
# ---> 15   movie_docs["overview vectors"] = word_vecs
#      16   movie_docs.head()
#
# /opt/anaconda3/envs/pytorch/lib/python3.8/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3038         else:
#    3039             # set column
# -> 3040             self._set_item(key, value)
#    3041
#    3042     def _setitem_slice(self, key: slice, value):
#
# /opt/anaconda3/envs/pytorch/lib/python3.8/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3115         self._ensure_valid_index(value)
#    3116         value = self._sanitize_column(key, value)
# -> 3117         NDFrame._set_item(self, key, value)
#    3118
#    3119         # check if we are modifying a copy
#
# /opt/anaconda3/envs/pytorch/lib/python3.8/site-packages/pandas/core/generic.py in _set_item(self, key, value)
#    3575         except KeyError:
#    3576             # This item wasn't present, just insert at end
# -> 3577             self._mgr.insert(len(self._info_axis), key, value)
#    3578             return
#    3579
#
# /opt/anaconda3/envs/pytorch/lib/python3.8/site-packages/pandas/core/internals/managers.py in insert(self, loc, item, value, allow_duplicates)
#    1187             value = _safe_reshape(value, (1,) + value.shape)
#    1188
# -> 1189         block = make_block(values=value, ndim=self.ndim, placement=slice(loc, loc + 1))
#    1190
#    1191         for blkno, count in _fast_count_smallints(self.blknos[loc:]):
#
# /opt/anaconda3/envs/pytorch/lib/python3.8/site-packages/pandas/core/internals/blocks.py in make_block(values, placement, klass, ndim, dtype)
#    2720         values = DatetimeArray._simple_new(values, dtype=dtype)
#    2721
# -> 2722     return klass(values, ndim=ndim, placement=placement)
#    2723
#    2724
#
# /opt/anaconda3/envs/pytorch/lib/python3.8/site-packages/pandas/core/internals/blocks.py in __init__(self, values, placement, ndim)
#     128
#     129         if self._validate_ndim and self.ndim and len(self.mgr_locs) != len(self.values):
# --> 130             raise ValueError(
#     131                 f"Wrong number of items passed {len(self.values)}, "
#     132                 f"placement implies {len(self.mgr_locs)}"
#
# ValueError: Wrong number of items passed 768, placement implies 1

# %%
def insert_movie_feature_vectors(word_vecs):
    list_word_vecs = []
    for i in range(len(word_vecs)):
        list_word_vecs.append(np.array(word_vecs[i]))
    len(list_word_vecs)
    movie_docs["overview vectors"] = list_word_vecs
    movie_docs.head()

# %%
insert_movie_feature_vectors()

# %%
get_recommendations("The Departed", 5, movie_docs)
# Out:
# vector shape:768
# ['Дура', 'Про любоff', 'На семи ветрах', 'Ι-4: Λούφα Και Απαλλαγή', 'Bad']

# %%
get_recommendations("The Departed", 5, movie_docs, "euclidian")
# Out:
# vector shape:768
# ['Donnie Brasco',
#  'Private Hell 36',
#  'Kounterfeit',
#  'The Alibi',
#  'The Departed']

# %%
get_recommendations("Toy Story", 5, movie_docs)
# Out:
# vector shape:768
# ['Ganes', 'Buffalo Running', 'Kalteva Torni', 'Bad', 'Endurance']

# %%
get_recommendations("Toy Story", 5, movie_docs, "euclidian")
# Out:
# vector shape:768
# ["Christmas Vacation 2: Cousin Eddie's Island Adventure",
#  'Frankenweenie',
#  'Toy Story 3',
#  'Toy Story 2',
#  'Toy Story']

# %%
get_recommendations("Happy Feet", 5, movie_docs)
# Out:
# vector shape:768
# ['Il segno di Venere',
#  'Water & Power: A California Heist',
#  'Endurance',
#  'Downeast',
#  'Bad']

# %%
get_recommendations("Happy Feet", 5, movie_docs, "euclidian")
# Out:
# vector shape:768
# ['Monster High: Welcome to Monster High',
#  'The Wayshower',
#  'The Trumpet Of The Swan',
#  'Jack Frost',
#  'Happy Feet']

# %%
get_recommendations("Whiplash", 5, movie_docs)
# Out:
# vector shape:768
# ['Дура', 'Про любоff', 'На семи ветрах', 'Kalteva Torni', 'Koroli i kapusta']

# %%
get_recommendations("Whiplash", 5, movie_docs, "euclidian")
# Out:
# vector shape:768
# ['Young Man with a Horn',
#  'The Derby Stallion',
#  'A Man Called Adam',
#  'Sympathy for Delicious',
#  'Whiplash']

# %%
# "Kill Bill: Vol. 1"
def recommend_for_all_metrics(movie_name):
  for metric in ["chebyshev",
                 "sokalmichener",
                 "sqeuclidean",
                 "hamming",
                 "cosine",
                 "euclidian",
                 "dice"]:
    recommendations = get_recommendations(movie_name,
                                          10,
                                          movie_docs,
                                          metric)
    print(recommendations)

# %%
recommend_for_all_metrics("The Matrix")
# Out:
# vector shape:768
# ['Interstellar', 'Flatland', 'Firebase', 'Lockout', 'Predestination']
# vector shape:768
# ['Salvation Boulevard', 'Scavengers', 'Surrogates', 'Cyborg X', 'The Matrix']
# vector shape:768
# ['Surrogates', 'Predestination', 'Lockout', '7 Below', 'Starship Troopers']
# vector shape:768
# ['Foxtrot', 'Die Farbe', 'The Prospects', 'Festival', 'Alone in the Wilderness']
# vector shape:768
# ['Наша Russia: Яйца судьбы', 'Ι-4: Λούφα Και Απαλλαγή', 'Про любоff', 'На семи ветрах', 'V Boy Idut Odni Stariki']
# vector shape:768
# ['Surrogates', 'Predestination', 'Lockout', '7 Below', 'Starship Troopers']
# vector shape:768
# ['صراع في الوادي', 'Горько!', 'മുംബൈ പോലീസ്', 'พี่ชาย', 'Metsän Tarina']

# %%
movie_row = movie_docs[movie_docs["original_title"] == "The Matrix"]
print(movie_row["overview"])
# Out:
# 2458    Set in the 22nd century, The Matrix tells the ...
# Name: overview, dtype: object

# %%
display(HTML(movie_row.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>original_title</th>
#       <th>overview</th>
#       <th>overview vectors</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2458</th>
#       <td>The Matrix</td>
#       <td>Set in the 22nd century, The Matrix tells the story of a computer hacker who joins a group of underground insurgents fighting the vast and powerful computers who now rule the earth.</td>
#       <td>[-0.35084718, -0.24244294, -0.1840358, -0.30705032, -0.15726152, -0.184679, 0.09660693, 0.35997182, 0.16252281, -0.33846983, -0.18280007, -0.14451303, -0.3491705, 0.7385647, 0.23709188, 0.35123006, -0.08983389, 0.28762984, 0.01069252, -0.005493727, -0.01478569, -0.21081218, 0.31973347, 0.57102394, -0.090251975, 0.024521315, -0.07400369, 0.1604857, 0.0006978912, 0.23801477, 0.15782556, -0.23305541, -0.33934858, -0.7046923, 0.3888474, 0.018715596, -0.1590166, 0.0396753, -0.0075969887, 0.14665444, -0.08141522, 0.13906074, -0.12336385, 0.18838067, 0.2794778, -0.43430367, -3.0222368, -0.112657234, -0.48416227, -0.0768291, 0.27748024, 0.13323325, 0.17570113, 0.12851852, 0.5941701, 0.508074, -0.4200568, 0.25307485, -0.11302263, 0.24359815, 0.39850366, 0.18041219, -0.25556263, -0.15677671, -0.12146113, 0.11462549, 0.03206719, 0.18937133, -0.38975123, 0.31198576, -0.60671777, 0.12976122, -0.18699339, -0.08338334, -0.19498147, 0.09981582, 0.045266017, 0.4789428, -0.2761243, -0.025746373, -0.24038945, 0.7126396, 0.5870525, 0.22910309, -0.16905083, 0.031426813, -0.43050867, -0.0044919495, 0.20402199, 0.5396829, -0.42927772, -0.33674845, -0.014269916, 0.5349731, 0.28014466, -0.39612612, 0.049040712, 0.15552673, -0.030129947, 0.6691768, ...]</td>
#     </tr>
#   </tbody>
# </table>

# %%
for column in metadata.columns:
  print(column)
# Out:
# adult
# belongs_to_collection
# budget
# genres
# homepage
# id
# imdb_id
# original_language
# original_title
# overview
# popularity
# poster_path
# production_companies
# production_countries
# release_date
# revenue
# runtime
# spoken_languages
# status
# tagline
# title
# video
# vote_average
# vote_count

# %%
display(HTML(metadata.head().to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>adult</th>
#       <th>belongs_to_collection</th>
#       <th>budget</th>
#       <th>genres</th>
#       <th>homepage</th>
#       <th>id</th>
#       <th>imdb_id</th>
#       <th>original_language</th>
#       <th>original_title</th>
#       <th>overview</th>
#       <th>popularity</th>
#       <th>poster_path</th>
#       <th>production_companies</th>
#       <th>production_countries</th>
#       <th>release_date</th>
#       <th>revenue</th>
#       <th>runtime</th>
#       <th>spoken_languages</th>
#       <th>status</th>
#       <th>tagline</th>
#       <th>title</th>
#       <th>video</th>
#       <th>vote_average</th>
#       <th>vote_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>False</td>
#       <td>{'id': 10194, 'name': 'Toy Story Collection', 'poster_path': '/7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg', 'backdrop_path': '/9FBwqcd9IRruEDUrTdcaafOMKUq.jpg'}</td>
#       <td>30000000</td>
#       <td>[{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': 10751, 'name': 'Family'}]</td>
#       <td>http://toystory.disney.com/toy-story</td>
#       <td>862</td>
#       <td>tt0114709</td>
#       <td>en</td>
#       <td>Toy Story</td>
#       <td>Led by Woody, Andy's toys live happily in his room until Andy's birthday brings Buzz Lightyear onto the scene. Afraid of losing his place in Andy's heart, Woody plots against Buzz. But when circumstances separate Buzz and Woody from their owner, the duo eventually learns to put aside their differences.</td>
#       <td>21.946943</td>
#       <td>/rhIRbceoE9lR4veEXuwCC2wARtG.jpg</td>
#       <td>[{'name': 'Pixar Animation Studios', 'id': 3}]</td>
#       <td>[{'iso_3166_1': 'US', 'name': 'United States of America'}]</td>
#       <td>1995-10-30</td>
#       <td>373554033.0</td>
#       <td>81.0</td>
#       <td>[{'iso_639_1': 'en', 'name': 'English'}]</td>
#       <td>Released</td>
#       <td>NaN</td>
#       <td>Toy Story</td>
#       <td>False</td>
#       <td>7.7</td>
#       <td>5415.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>False</td>
#       <td>NaN</td>
#       <td>65000000</td>
#       <td>[{'id': 12, 'name': 'Adventure'}, {'id': 14, 'name': 'Fantasy'}, {'id': 10751, 'name': 'Family'}]</td>
#       <td>NaN</td>
#       <td>8844</td>
#       <td>tt0113497</td>
#       <td>en</td>
#       <td>Jumanji</td>
#       <td>When siblings Judy and Peter discover an enchanted board game that opens the door to a magical world, they unwittingly invite Alan -- an adult who's been trapped inside the game for 26 years -- into their living room. Alan's only hope for freedom is to finish the game, which proves risky as all three find themselves running from giant rhinoceroses, evil monkeys and other terrifying creatures.</td>
#       <td>17.015539</td>
#       <td>/vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg</td>
#       <td>[{'name': 'TriStar Pictures', 'id': 559}, {'name': 'Teitler Film', 'id': 2550}, {'name': 'Interscope Communications', 'id': 10201}]</td>
#       <td>[{'iso_3166_1': 'US', 'name': 'United States of America'}]</td>
#       <td>1995-12-15</td>
#       <td>262797249.0</td>
#       <td>104.0</td>
#       <td>[{'iso_639_1': 'en', 'name': 'English'}, {'iso_639_1': 'fr', 'name': 'Français'}]</td>
#       <td>Released</td>
#       <td>Roll the dice and unleash the excitement!</td>
#       <td>Jumanji</td>
#       <td>False</td>
#       <td>6.9</td>
#       <td>2413.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>False</td>
#       <td>{'id': 119050, 'name': 'Grumpy Old Men Collection', 'poster_path': '/nLvUdqgPgm3F85NMCii9gVFUcet.jpg', 'backdrop_path': '/hypTnLot2z8wpFS7qwsQHW1uV8u.jpg'}</td>
#       <td>0</td>
#       <td>[{'id': 10749, 'name': 'Romance'}, {'id': 35, 'name': 'Comedy'}]</td>
#       <td>NaN</td>
#       <td>15602</td>
#       <td>tt0113228</td>
#       <td>en</td>
#       <td>Grumpier Old Men</td>
#       <td>A family wedding reignites the ancient feud between next-door neighbors and fishing buddies John and Max. Meanwhile, a sultry Italian divorcée opens a restaurant at the local bait shop, alarming the locals who worry she'll scare the fish away. But she's less interested in seafood than she is in cooking up a hot time with Max.</td>
#       <td>11.7129</td>
#       <td>/6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg</td>
#       <td>[{'name': 'Warner Bros.', 'id': 6194}, {'name': 'Lancaster Gate', 'id': 19464}]</td>
#       <td>[{'iso_3166_1': 'US', 'name': 'United States of America'}]</td>
#       <td>1995-12-22</td>
#       <td>0.0</td>
#       <td>101.0</td>
#       <td>[{'iso_639_1': 'en', 'name': 'English'}]</td>
#       <td>Released</td>
#       <td>Still Yelling. Still Fighting. Still Ready for Love.</td>
#       <td>Grumpier Old Men</td>
#       <td>False</td>
#       <td>6.5</td>
#       <td>92.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>False</td>
#       <td>NaN</td>
#       <td>16000000</td>
#       <td>[{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}]</td>
#       <td>NaN</td>
#       <td>31357</td>
#       <td>tt0114885</td>
#       <td>en</td>
#       <td>Waiting to Exhale</td>
#       <td>Cheated on, mistreated and stepped on, the women are holding their breath, waiting for the elusive "good man" to break a string of less-than-stellar lovers. Friends and confidants Vannah, Bernie, Glo and Robin talk it all out, determined to find a better way to breathe.</td>
#       <td>3.859495</td>
#       <td>/16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg</td>
#       <td>[{'name': 'Twentieth Century Fox Film Corporation', 'id': 306}]</td>
#       <td>[{'iso_3166_1': 'US', 'name': 'United States of America'}]</td>
#       <td>1995-12-22</td>
#       <td>81452156.0</td>
#       <td>127.0</td>
#       <td>[{'iso_639_1': 'en', 'name': 'English'}]</td>
#       <td>Released</td>
#       <td>Friends are the people who let you be yourself... and never let you forget it.</td>
#       <td>Waiting to Exhale</td>
#       <td>False</td>
#       <td>6.1</td>
#       <td>34.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>False</td>
#       <td>{'id': 96871, 'name': 'Father of the Bride Collection', 'poster_path': '/nts4iOmNnq7GNicycMJ9pSAn204.jpg', 'backdrop_path': '/7qwE57OVZmMJChBpLEbJEmzUydk.jpg'}</td>
#       <td>0</td>
#       <td>[{'id': 35, 'name': 'Comedy'}]</td>
#       <td>NaN</td>
#       <td>11862</td>
#       <td>tt0113041</td>
#       <td>en</td>
#       <td>Father of the Bride Part II</td>
#       <td>Just when George Banks has recovered from his daughter's wedding, he receives the news that she's pregnant ... and that George's wife, Nina, is expecting too. He was planning on selling their home, but that's a plan that -- like George -- will have to change with the arrival of both a grandchild and a kid of his own.</td>
#       <td>8.387519</td>
#       <td>/e64sOI48hQXyru7naBFyssKFxVd.jpg</td>
#       <td>[{'name': 'Sandollar Productions', 'id': 5842}, {'name': 'Touchstone Pictures', 'id': 9195}]</td>
#       <td>[{'iso_3166_1': 'US', 'name': 'United States of America'}]</td>
#       <td>1995-02-10</td>
#       <td>76578911.0</td>
#       <td>106.0</td>
#       <td>[{'iso_639_1': 'en', 'name': 'English'}]</td>
#       <td>Released</td>
#       <td>Just When His World Is Back To Normal... He's In For The Surprise Of His Life!</td>
#       <td>Father of the Bride Part II</td>
#       <td>False</td>
#       <td>5.7</td>
#       <td>173.0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Step 2: Overviews are short and not descriptive enough so Let's use plot summaries to get feature vectors
# **source:** https://www.kaggle.com/jrobischon/wikipedia-movie-plots

# %%
movie_plots = pd.read_csv('/home/gsoykan20/Desktop/inzva/week2/homework-20210808T093349Z-001/homework/Wikipedia Movie Plots/wiki_movie_plots_deduped.csv', low_memory=False)
# metadata['overview'] = metadata['overview'].fillna('')

# %%
display(HTML(movie_plots.head().to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Release Year</th>
#       <th>Title</th>
#       <th>Origin/Ethnicity</th>
#       <th>Director</th>
#       <th>Cast</th>
#       <th>Genre</th>
#       <th>Wiki Page</th>
#       <th>Plot</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1901</td>
#       <td>Kansas Saloon Smashers</td>
#       <td>American</td>
#       <td>Unknown</td>
#       <td>NaN</td>
#       <td>unknown</td>
#       <td>https://en.wikipedia.org/wiki/Kansas_Saloon_Smashers</td>
#       <td>A bartender is working at a saloon, serving drinks to customers. After he fills a stereotypically Irish man's bucket with beer, Carrie Nation and her followers burst inside. They assault the Irish man, pulling his hat over his eyes and then dumping the beer over his head. The group then begin wrecking the bar, smashing the fixtures, mirrors, and breaking the cash register. The bartender then sprays seltzer water in Nation's face before a group of policemen appear and order everybody to leave.[1]</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1901</td>
#       <td>Love by the Light of the Moon</td>
#       <td>American</td>
#       <td>Unknown</td>
#       <td>NaN</td>
#       <td>unknown</td>
#       <td>https://en.wikipedia.org/wiki/Love_by_the_Light_of_the_Moon</td>
#       <td>The moon, painted with a smiling face hangs over a park at night. A young couple walking past a fence learn on a railing and look up. The moon smiles. They embrace, and the moon's smile gets bigger. They then sit down on a bench by a tree. The moon's view is blocked, causing him to frown. In the last scene, the man fans the woman with his hat because the moon has left the sky and is perched over her shoulder to see everything better.</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1901</td>
#       <td>The Martyred Presidents</td>
#       <td>American</td>
#       <td>Unknown</td>
#       <td>NaN</td>
#       <td>unknown</td>
#       <td>https://en.wikipedia.org/wiki/The_Martyred_Presidents</td>
#       <td>The film, just over a minute long, is composed of two shots. In the first, a girl sits at the base of an altar or tomb, her face hidden from the camera. At the center of the altar, a viewing portal displays the portraits of three U.S. Presidents—Abraham Lincoln, James A. Garfield, and William McKinley—each victims of assassination.\r\nIn the second shot, which runs just over eight seconds long, an assassin kneels feet of Lady Justice.</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1901</td>
#       <td>Terrible Teddy, the Grizzly King</td>
#       <td>American</td>
#       <td>Unknown</td>
#       <td>NaN</td>
#       <td>unknown</td>
#       <td>https://en.wikipedia.org/wiki/Terrible_Teddy,_the_Grizzly_King</td>
#       <td>Lasting just 61 seconds and consisting of two shots, the first shot is set in a wood during winter. The actor representing then vice-president Theodore Roosevelt enthusiastically hurries down a hillside towards a tree in the foreground. He falls once, but rights himself and cocks his rifle. Two other men, bearing signs reading "His Photographer" and "His Press Agent" respectively, follow him into the shot; the photographer sets up his camera. "Teddy" aims his rifle upward at the tree and fells what appears to be a common house cat, which he then proceeds to stab. "Teddy" holds his prize aloft, and the press agent takes notes. The second shot is taken in a slightly different part of the wood, on a path. "Teddy" rides the path on his horse towards the camera and out to the left of the shot, followed closely by the press agent and photographer, still dutifully holding their signs.</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1902</td>
#       <td>Jack and the Beanstalk</td>
#       <td>American</td>
#       <td>George S. Fleming, Edwin S. Porter</td>
#       <td>NaN</td>
#       <td>unknown</td>
#       <td>https://en.wikipedia.org/wiki/Jack_and_the_Beanstalk_(1902_film)</td>
#       <td>The earliest known adaptation of the classic fairytale, this films shows Jack trading his cow for the beans, his mother forcing him to drop them in the front yard, and beig forced upstairs. As he sleeps, Jack is visited by a fairy who shows him glimpses of what will await him when he ascends the bean stalk. In this version, Jack is the son of a deposed king. When Jack wakes up, he finds the beanstalk has grown and he climbs to the top where he enters the giant's home. The giant finds Jack, who narrowly escapes. The giant chases Jack down the bean stalk, but Jack is able to cut it down before the giant can get to safety. He falls and is killed as Jack celebrates. The fairy then reveals that Jack may return home as a prince.</td>
#     </tr>
#   </tbody>
# </table>

# %%
show_as_html(movie_plots[movie_plots["Title"] == "The Matrix"])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Release Year</th>
#       <th>Title</th>
#       <th>Origin/Ethnicity</th>
#       <th>Director</th>
#       <th>Cast</th>
#       <th>Genre</th>
#       <th>Wiki Page</th>
#       <th>Plot</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>13509</th>
#       <td>1999</td>
#       <td>The Matrix</td>
#       <td>American</td>
#       <td>Andy Wachowski, Larry Wachowski</td>
#       <td>Keanu Reeves, Laurence Fishburne, Carrie-Anne Moss, Hugo Weaving, Joe Pantoliano</td>
#       <td>science fiction</td>
#       <td>https://en.wikipedia.org/wiki/The_Matrix</td>
#       <td>A woman is cornered by police in an abandoned hotel; after overpowering them with superhuman abilities, a group of sinister superhuman grey green-suited Agents leads the police in a rooftop pursuit. She answers a ringing public telephone and vanishes.\r\nComputer programmer Thomas Anderson, living a double life as the hacker "Neo", feels something is wrong with the world and is puzzled by repeated online encounters with the cryptic phrase "the Matrix". The woman, Trinity, contacts him, saying that a man named Morpheus can explain its meaning; however, the Agents, led by Agent Smith, apprehend Neo and attempt to threaten him into helping them capture the "terrorist" Morpheus. Undeterred, Neo meets Morpheus, who offers him a choice between a red pill that will show him the truth about the Matrix, and a blue pill that will return him to his former life. After swallowing the red pill, his reality disintegrates and Neo awakens, naked, weak and hairless, in a liquid-filled pod, one of countless others connected by cables to an elaborate electrical system. He is rescued and brought aboard Morpheus' hovercraft, the Nebuchadnezzar.\r\nAs Neo recuperates, Morpheus explains the truth: in the 21st century, intelligent machines waged war against their human creators. When humans blocked the machines' access to solar energy, the machines retaliated by harvesting the humans' bioelectric power. The Matrix is a shared simulation of the world, in which the minds of the harvested humans are trapped and pacified. All free humans live in Zion, the last refuge in the real world. Morpheus and his crew are a group of rebels who hack into the Matrix to "unplug" enslaved humans and recruit them; their understanding of the simulated reality enables them to bend its physical laws, granting them superhuman abilities. Morpheus warns Neo that death within the Matrix also kills the physical body, and that the Agents are powerful sentient programs that eliminate threats to the system. Neo's prowess during virtual combat training lends credence to Morpheus' belief that Neo is "the One", an especially powerful human prophesied to free humans and end the war.\r\nThe group enters the Matrix to visit the Oracle, a prophet who predicted the emergence of the One. She implies that Neo is not the One and warns Neo that he will have to choose between Morpheus' life and his own. Before they can leave the Matrix, the group is ambushed by Agents and tactical police alerted by Cypher, a crew member who betrayed Morpheus to Smith in exchange for a comfortable life back in the Matrix. Morpheus allows himself to be captured so Neo and the rest of the crew can escape. Cypher exits the Matrix and murders several crew members as they lie defenseless in the real world. As he prepares to disconnect Neo and Trinity, Tank, a crewman whom he had left for dead, kills him.\r\nIn the Matrix, the Agents interrogate Morpheus to learn his access codes to the mainframe computer in Zion. Tank proposes killing Morpheus to prevent this, but Neo, believing that he is not the One, resolves to return to the Matrix to rescue Morpheus; Trinity insists she accompany him. While rescuing Morpheus, Neo gains confidence in his abilities, performing feats comparable to the Agents'. Morpheus and Trinity exit the Matrix, but Smith ambushes and kills Neo before he can leave. In the real world, machines called Sentinels attack the Nebuchadnezzar. Trinity whispers to Neo that he can't be dead because she loves him and the Oracle told her that she would fall in love with the One. She kisses Neo and he revives with the power to perceive and control the Matrix. He effortlessly defeats Smith and leaves the Matrix just as the ship's electromagnetic pulse weapon disables the attacking Sentinels.\r\nLater, Neo makes a telephone call inside the Matrix, promising the machines that he will show their prisoners "a world where anything is possible". He hangs up and flies into the sky.</td>
#     </tr>
#   </tbody>
# </table>

# %%
intersected = pd.DataFrame(columns=movie_docs.columns)
for idx, row in tqdm(movie_docs.iterrows(), total=len(movie_docs)):
    original_title_in_movie_docs = row["original_title"]
    try:
        intersected_row = movie_plots[movie_plots["Title"] == original_title_in_movie_docs]
        intersected = intersected.append(intersected_row, ignore_index=True)
    except:
        print("not match for " + original_title_in_movie_docs)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=45466.0), HTML(value='')))

# %%
for idx, row in tqdm(movie_docs.iterrows(), total=len(movie_docs)):
    original_title_in_movie_docs = row["original_title"]
    try:
        intersected_row = movie_plots[movie_plots["Title"] == original_title_in_movie_docs]
        movie_docs.iloc[idx]["Plot"] = intersected_row["Plot"].values[0]
    except:
        movie_docs.iloc[idx]["Plot"] = None
        print("not match for " + original_title_in_movie_docs)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=45466.0), HTML(value='')))
# not match for La Cité des Enfants Perdus
# not match for 摇啊摇，摇到外婆桥
# not match for Guillaumet, les ailes du courage
# not match for Across the Sea of Time
# not match for How To Make An American Quilt
# not match for Se7en
# not match for Guardian Angel
# not match for Lamerica
# not match for Georgia
# not match for Kids of the Round Table
# not match for Il postino
# not match for Le confessionnal
# not match for Two If by Sea
# not match for Lawnmower Man 2: Beyond Cyberspace
# not match for Gazon maudit
# not match for Kicking and Screaming
# not match for Les misérables
# not match for Nico Icon
# not match for بادکنک سفید
# not match for Antonia
# not match for Once Upon a Time... When We Were Colored
# not match for Last Summer in the Hamptons
# not match for The Journey of August King
# not match for La Haine
# not match for Shopping
# not match for Heidi Fleiss: Hollywood Madam
# not match for Keiner liebt mich
# not match for Catwalk
# not match for Headless Body in Topless Bar
# not match for 紅番區
# not match for Le Bonheur est dans le pré
# not match for Anne Frank Remembered
# not match for The Young Poisoner's Handbook
# not match for Steal Big Steal Little
# not match for The Boys of St. Vincent
# not match for 重慶森林
# not match for L'uomo delle stelle
# not match for The NeverEnding Story III
# not match for صمت القصور
# not match for Jupiter's Wife
# not match for Pie in the Sky
# not match for Frankie Starlight
# not match for Nueba Yol
# not match for Sonic Outlaws
# not match for From the Journals of Jean Seberg
# not match for The Neon Bible
# not match for Gospa
# not match for Belle de jour
# not match for Crumb
# not match for Die Hard: With a Vengeance
# not match for Free Willy 2 - The Adventure Home
# not match for Love & Human Remains
# not match for Mute Witness
# not match for Nadja
# not match for Something to Talk About
# not match for Les parapluies de Cherbourg
# not match for Total Eclipse
# not match for Unstrung Heroes
# not match for Unzipped
# not match for Утомлённые солнцем
# not match for Before the Rain
# not match for The Babysitter
# not match for Dream Man
# not match for Destiny Turns on the Radio
# not match for 飲食男女
# not match for Farinelli
# not match for Hoop Dreams
# not match for Heavenly Creatures
# not match for The Jerky Boys
# not match for Star Wars
# not match for Ladybird Ladybird
# not match for L'Enfer
# not match for Como agua para chocolate
# not match for Mi Vida Loca
# not match for New Jersey Drive
# not match for New York Cop
# not match for Beyond Bedlam
# not match for Nemesis 2 - Nebula
# not match for Nina Takes a Lover
# not match for Once Were Warriors
# not match for Léon
# not match for The Perez Family
# not match for A Pyromaniac's Love Story
# not match for Pushing Hands
# not match for La Reine Margot
# not match for Prêt-à-Porter
# not match for Trois couleurs : Rouge
# not match for Trois couleurs : Bleu
# not match for Trois couleurs : Blanc
# not match for Pao Da Shuang Deng
# not match for Rent-a-Kid
# not match for Relative Fear
# not match for Fresa y chocolate
# not match for Senior Trip
# not match for 活着
# not match for Tales from the Crypt: Demon Knight
# not match for Star Trek: Generations
# not match for Les Transmutations imperceptibles
# not match for Pooh's Heffalump Halloween Movie
# not match for L'Homme orchestre
# not match for Nouvelles luttes extravagantes
# not match for Deep Hearts
# not match for San Michele aveva un gallo
# not match for Shadow of the Blair Witch
# not match for The Burkittsville 7
# not match for Caged Heat 3000
# not match for رگ خواب
# not match for Siglo ng Pagluluwal
# not match for Satana likuyushchiy
# not match for Queerama

# %%
movie_plots[movie_plots["Title"] == "black sun"]
# Out:
# Empty DataFrame
# Columns: [Release Year, Title, Origin/Ethnicity, Director, Cast, Genre, Wiki Page, Plot]
# Index: []

# %%
def generate_movie_docs_with_plots_vectors_from_distilbert(mix_overview_and_plot=False,
                                                           save_name="movie_lens_overview_with_plots_distilbert_vecs.npy"):
    def get_cls_vec(text):
            token_inputs = distilbert_tokenizer(text, return_tensors="pt", max_length=512).to('cuda')
            return distilbert_model(**token_inputs).last_hidden_state[0, 0].cpu().detach().numpy()

    movie_docs_vectors = []
    for idx, row in tqdm(movie_docs.iterrows(), total=len(movie_docs)):
        if row["Plot"] != None and len(row["Plot"]) >= len(row["overview"]):
            if mix_overview_and_plot:
                plot_vec = get_cls_vec(row["Plot"])
                overview_vec = get_cls_vec(row["overview"])
                cls_feature_vec = (plot_vec + overview_vec) / 2
            else:
                cls_feature_vec = get_cls_vec(row["Plot"])
            #print("Plot is used for " + str(row["original_title"]))
        else:
            overview = row["overview"]
            cls_feature_vec = get_cls_vec(overview)
        movie_docs_vectors.append(cls_feature_vec)

    with open('./' + save_name, 'wb') as f:
        np.save(f, np.array(movie_docs_vectors), allow_pickle=True)

# %%
generate_movie_docs_with_plots_vectors_from_distilbert()
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=45466.0), HTML(value='')))
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Plot is used for Toy Story
# Plot is used for Jumanji
# Plot is used for Grumpier Old Men
# Plot is used for Waiting to Exhale
# Plot is used for Father of the Bride Part II
# Plot is used for Heat
# Plot is used for Sabrina
# Plot is used for Tom and Huck
# Plot is used for Sudden Death
# Plot is used for GoldenEye
# Plot is used for The American President
# Plot is used for Dracula: Dead and Loving It
# Plot is used for Balto
# Plot is used for Nixon
# Plot is used for Cutthroat Island
# Plot is used for Casino
# Plot is used for Sense and Sensibility
# Plot is used for Four Rooms
# Plot is used for Ace Ventura: When Nature Calls
# Plot is used for Money Train
# Plot is used for Get Shorty
# Plot is used for Copycat
# Plot is used for Assassins
# Plot is used for Powder
# Plot is used for Leaving Las Vegas
# Plot is used for Othello
# Plot is used for Now and Then
# Plot is used for Persuasion
# Plot is used for Dangerous Minds
# Plot is used for Twelve Monkeys
# Plot is used for Babe
# Plot is used for Dead Man Walking
# Plot is used for It Takes Two
# Plot is used for Clueless
# Plot is used for Cry, the Beloved Country
# Plot is used for Richard III
# Plot is used for Dead Presidents
# Plot is used for Restoration
# Plot is used for Mortal Kombat
# Plot is used for Pocahontas
# Plot is used for When Night Is Falling
# Plot is used for The Usual Suspects
# Plot is used for Mighty Aphrodite
# Plot is used for The Big Green
# Plot is used for Home for the Holidays
# Plot is used for The Indian in the Cupboard
# Plot is used for Eye for an Eye
# Plot is used for Mr. Holland's Opus
# Plot is used for Don't Be a Menace to South Central While Drinking Your Juice in the Hood
# Plot is used for Bio-Dome
# Plot is used for Two Bits
# Plot is used for Friday
# Plot is used for From Dusk Till Dawn
# Plot is used for Fair Game
# Plot is used for Bed of Roses
# Plot is used for Big Bully
# Plot is used for Screamers
# Plot is used for The Crossing Guard
# Plot is used for The Juror
# Plot is used for Things to Do in Denver When You're Dead
# Plot is used for Angels and Insects
# Plot is used for White Squall
# Plot is used for Dunston Checks In
# Plot is used for Black Sheep
# Plot is used for Nick of Time
# Plot is used for Mary Reilly
# Plot is used for Vampire in Brooklyn
# Plot is used for Beautiful Girls
# Plot is used for Broken Arrow
# Plot is used for A Midwinter's Tale
# Plot is used for City Hall
# Plot is used for Bottle Rocket
# Plot is used for Mr. Wrong
# Plot is used for Unforgettable
# Plot is used for Happy Gilmore
# Plot is used for The Bridges of Madison County
# Plot is used for Muppet Treasure Island
# Plot is used for Braveheart
# Plot is used for Taxi Driver
# Plot is used for Before and After
# Plot is used for Margaret's Museum
# Plot is used for If Lucy Fell
# Plot is used for Race the Sun
# Plot is used for Boomerang
# Plot is used for Flirting with Disaster
# Plot is used for Angela
# Plot is used for Jade
# Plot is used for Down Periscope
# Plot is used for Man of the Year
# Plot is used for Target
# Plot is used for Up Close & Personal
# Plot is used for The Birdcage
# Plot is used for The Brothers McMullen
# Plot is used for Bad Boys
# Plot is used for The Amazing Panda Adventure
# Plot is used for The Basketball Diaries
# Plot is used for An Awfully Big Adventure
# Plot is used for Amateur
# Plot is used for Apollo 13
# Plot is used for Rob Roy
# Plot is used for The Addiction
# Plot is used for Batman Forever
# Plot is used for Beyond Rangoon
# Plot is used for Blue in the Face
# Plot is used for Canadian Bacon
# Plot is used for Casper
# Plot is used for Clockers
# Plot is used for Congo
# Plot is used for Crimson Tide
# Plot is used for Desperado
# Plot is used for Devil in a Blue Dress
# Plot is used for The Doom Generation
# Plot is used for Feast of July
# Plot is used for First Knight
# Plot is used for Hackers
# Plot is used for Jeffrey
# Plot is used for Johnny Mnemonic
# Plot is used for Judge Dredd
# Plot is used for Jury Duty
# Plot is used for Kids
# Plot is used for Living in Oblivion
# Plot is used for Lord of Illusions
# Plot is used for Mad Love
# Plot is used for Mallrats
# Plot is used for Mighty Morphin Power Rangers: The Movie
# Plot is used for Moonlight and Valentino
# Plot is used for The Net
# Plot is used for Nine Months
# Plot is used for Party Girl
# Plot is used for The Prophecy
# Plot is used for Reckless
# Plot is used for Safe
# Plot is used for The Scarlet Letter
# Plot is used for The Show
# Plot is used for Showgirls
# Plot is used for Species
# Plot is used for The Stars Fell on Henrietta
# Plot is used for Strange Days
# Plot is used for The Tie That Binds
# Plot is used for Three Wishes
# Plot is used for To Wong Foo, Thanks for Everything! Julie Newmar
# Plot is used for Under Siege 2: Dark Territory
# Plot is used for A Walk in the Clouds
# Plot is used for Waterworld
# Plot is used for White Man's Burden
# Plot is used for Wild Bill
# Plot is used for The Browning Version
# Plot is used for Bushwhacked
# Plot is used for Before Sunrise
# Plot is used for Billy Madison
# Plot is used for Boys on the Side
# Plot is used for The Cure
# Plot is used for Castle Freak
# Plot is used for Circle of Friends
# Plot is used for Clerks
# Plot is used for Don Juan DeMarco
# Plot is used for Disclosure
# Plot is used for Drop Zone
# Plot is used for Death and the Maiden
# Plot is used for Dolores Claiborne
# Plot is used for Dumb and Dumber
# Plot is used for Exotica
# Plot is used for Exit to Eden
# Plot is used for Ed Wood
# Plot is used for French Kiss
# Plot is used for Forget Paris
# Plot is used for Far from Home: The Adventures of Yellow Dog
# Plot is used for A Goofy Movie
# Plot is used for Hideaway
# Plot is used for Fluke
# Plot is used for Gordy
# Plot is used for Gumby: The Movie
# Plot is used for The Glass Shield
# Plot is used for Houseguest
# Plot is used for Immortal Beloved
# Plot is used for Heavyweights
# Plot is used for I.Q.
# Plot is used for Interview with the Vampire
# Plot is used for Jefferson in Paris
# Plot is used for Junior
# Plot is used for Just Cause
# Plot is used for A Kid in King Arthur's Court
# Plot is used for Kiss of Death
# Plot is used for Little Women
# Plot is used for A Little Princess
# Plot is used for Legends of the Fall
# Plot is used for Major Payne
# Plot is used for Little Odessa
# Plot is used for Love Affair
# Plot is used for Losing Isaiah
# Plot is used for The Madness of King George
# Plot is used for Man of the House
# Plot is used for Mixed Nuts
# Plot is used for Milk Money
# Plot is used for Miracle on 34th Street
# Plot is used for Miami Rhapsody
# Plot is used for My Family
# Plot is used for Murder in the First
# Plot is used for Nell
# Plot is used for Natural Born Killers
# Plot is used for Only You
# Plot is used for Poison Ivy II: Lily
# Plot is used for Outbreak
# Plot is used for Pulp Fiction
# Plot is used for Panther
# Plot is used for Priest
# Plot is used for Quiz Show
# Plot is used for Picture Bride
# Plot is used for The Quick and the Dead
# Plot is used for Roommates
# Plot is used for Stuart Saves His Family
# Plot is used for The Swan Princess
# Plot is used for The Secret of Roan Inish
# Plot is used for The Specialist
# Plot is used for Stargate
# Plot is used for The Santa Clause
# Plot is used for The Shawshank Redemption
# Plot is used for Shallow Grave
# Plot is used for Suture
# Plot is used for Swimming with Sharks
# Plot is used for The Sum of Us
# Plot is used for Tank Girl
# Plot is used for Tom & Viv
# Plot is used for Village of the Damned
# Plot is used for Tommy Boy
# Plot is used for The Walking Dead
# Plot is used for What's Eating Gilbert Grape
# Plot is used for Virtuosity
# Plot is used for While You Were Sleeping
# Plot is used for The War
# Plot is used for Double Happiness
# Plot is used for Muriel's Wedding
# Plot is used for The Baby-Sitters Club
# Plot is used for Ace Ventura: Pet Detective
# Plot is used for Bitter Moon
# Plot is used for Clear and Present Danger
# Plot is used for The Client
# Plot is used for Corrina, Corrina
# Plot is used for Crooklyn
# Plot is used for The Crow
# Plot is used for Cobb
# Plot is used for The Flintstones
# Plot is used for Forrest Gump
# Plot is used for Four Weddings and a Funeral
# Plot is used for Higher Learning
# Plot is used for I Like It Like That
# Plot is used for It Could Happen to You
# Plot is used for The Jungle Book
# Plot is used for The Lion King
# Plot is used for Little Buddha
# Plot is used for The Mask
# Plot is used for Maverick
# Plot is used for The Paper
# Plot is used for Reality Bites
# Plot is used for Red Rock West
# Plot is used for The River Wild
# Plot is used for Speed
# Plot is used for Speechless
# Plot is used for Timecop
# Plot is used for True Lies
# Plot is used for When a Man Loves a Woman
# Plot is used for Wolf
# Plot is used for Wyatt Earp
# Plot is used for S.F.W.
# Plot is used for A Low Down Dirty Shame
# Plot is used for Faster, Pussycat! Kill! Kill!
# Plot is used for Jason's Lyric
# Plot is used for The Secret Adventures of Tom Thumb
# Plot is used for Street Fighter
# Plot is used for Coldblooded
# Plot is used for Fall Time
# Plot is used for Mirage
# Plot is used for Open Season
# Plot is used for Highlander III: The Sorcerer
# Plot is used for In the Mouth of Madness
# Plot is used for 8 Seconds
# Plot is used for Above the Rim
# Plot is used for Addams Family Values
# Plot is used for The Age of Innocence
# Plot is used for Airheads
# Plot is used for The Air Up There
# Plot is used for Another Stakeout
# Plot is used for Bad Girls
# Plot is used for Barcelona
# Plot is used for The Beverly Hillbillies
# Plot is used for Beverly Hills Cop III
# Plot is used for Black Beauty
# Plot is used for Blown Away
# Plot is used for Blue Chips
# Plot is used for Blue Sky
# Plot is used for Body Snatchers
# Plot is used for Boxing Helena
# Plot is used for A Bronx Tale
# Plot is used for Cabin Boy
# Plot is used for Carlito's Way
# Plot is used for City Slickers II: The Legend of Curly's Gold
# Plot is used for Clean Slate
# Plot is used for Cliffhanger
# Plot is used for Coneheads
# Plot is used for Color of Night
# Plot is used for The Cowboy Way
# Plot is used for Dangerous Game
# Plot is used for Dave
# Plot is used for Dazed and Confused
# Plot is used for Demolition Man
# Plot is used for Even Cowgirls Get the Blues
# Plot is used for The Favor
# Plot is used for Fearless
# Plot is used for Fear of a Black Hat
# Plot is used for With Honors
# Plot is used for Flesh and Bone
# Plot is used for The Firm
# Plot is used for Free Willy
# Plot is used for Fresh
# Plot is used for The Fugitive
# Plot is used for Geronimo: An American Legend
# Plot is used for The Getaway
# Plot is used for Getting Even with Dad
# Plot is used for Go Fish
# Plot is used for Guilty as Sin
# Plot is used for Hard Target
# Plot is used for Heaven & Earth
# Plot is used for Hot Shots! Part Deux
# Plot is used for The Englishman Who Went Up a Hill But Came Down a Mountain
# Plot is used for The House of the Spirits
# Plot is used for House Party 3
# Plot is used for The Hudsucker Proxy
# Plot is used for I'll Do Anything
# Plot is used for In the Army Now
# Plot is used for In the Line of Fire
# Plot is used for The Inkwell
# Plot is used for What's Love Got to Do with It
# Plot is used for Jimmy Hollywood
# Plot is used for Judgment Night
# Plot is used for Jurassic Park
# Plot is used for Kalifornia
# Plot is used for Killing Zoe
# Plot is used for Lassie
# Plot is used for Last Action Hero
# Plot is used for Lightning Jack
# Plot is used for M. Butterfly
# Plot is used for Made in America
# Plot is used for Malice
# Plot is used for Manhattan Murder Mystery
# Plot is used for Menace II Society
# Plot is used for Executive Decision
# Plot is used for Much Ado About Nothing
# Plot is used for Mr. Jones
# Plot is used for Mrs. Doubtfire
# Plot is used for Naked
# Plot is used for The Next Karate Kid
# Plot is used for No Escape
# Plot is used for North
# Plot is used for Orlando
# Plot is used for A Perfect World
# Plot is used for Philadelphia
# Plot is used for The Piano
# Plot is used for Poetic Justice
# Plot is used for The Puppet Masters
# Plot is used for Radioland Murders
# Plot is used for The Ref
# Plot is used for The Remains of the Day
# Plot is used for Renaissance Man
# Plot is used for Rising Sun
# Plot is used for The Road to Wellville
# Plot is used for RoboCop 3
# Plot is used for Robin Hood: Men in Tights
# Plot is used for Romeo Is Bleeding
# Plot is used for Romper Stomper
# Plot is used for Rudy
# Plot is used for Schindler's List
# Plot is used for The Scout
# Plot is used for Second Best
# Plot is used for The Secret Garden
# Plot is used for Serial Mom
# Plot is used for The Shadow
# Plot is used for Shadowlands
# Plot is used for Short Cuts
# Plot is used for A Simple Twist of Fate
# Plot is used for Sirens
# Plot is used for Six Degrees of Separation
# Plot is used for Sleepless in Seattle
# Plot is used for Sliver
# Plot is used for Blade Runner
# Plot is used for Son in Law
# Plot is used for So I Married an Axe Murderer
# Plot is used for Striking Distance
# Plot is used for Super Mario Bros.
# Plot is used for Surviving the Game
# Plot is used for Thirty Two Short Films About Glenn Gould
# Plot is used for Threesome
# Plot is used for The Nightmare Before Christmas
# Plot is used for The Three Musketeers
# Plot is used for Tombstone
# Plot is used for Trial by Jury
# Plot is used for True Romance
# Plot is used for The Pagemaster
# Plot is used for Welcome to the Dollhouse
# Plot is used for Chasers
# Plot is used for Naked in New York
# Plot is used for Bhaji on the Beach
# Plot is used for Little Big League
# Plot is used for Spanking the Monkey
# Plot is used for The Little Rascals
# Plot is used for Andre
# Plot is used for Princess Caraboo
# Plot is used for The Brady Bunch Movie
# Plot is used for Home Alone
# Plot is used for Ghost
# Plot is used for Aladdin
# Plot is used for Terminator 2: Judgment Day
# Plot is used for Dances with Wolves
# Plot is used for Batman
# Plot is used for The Silence of the Lambs
# Plot is used for Snow White and the Seven Dwarfs
# Plot is used for Beauty and the Beast
# Plot is used for Pinocchio
# Plot is used for Pretty Woman
# Plot is used for The Wild Bunch
# Plot is used for Love and a .45
# Plot is used for The Wooden Man's Bride
# Plot is used for Bye Bye Love
# Plot is used for One Fine Day
# Plot is used for Fargo
# Plot is used for Homeward Bound II: Lost in San Francisco
# Plot is used for Heavy Metal
# Plot is used for Hellraiser: Bloodline
# Plot is used for The Pallbearer
# Plot is used for Jane Eyre
# Plot is used for The Aristocats
# Plot is used for Two Much
# Plot is used for Ed
# Plot is used for A Thin Line Between Love and Hate
# Plot is used for The Last Supper
# Plot is used for Primal Fear
# Plot is used for All Dogs Go to Heaven 2
# Plot is used for Land and Freedom
# Plot is used for Theodore Rex
# Plot is used for A Family Thing
# Plot is used for Sgt. Bilko
# Plot is used for Girl 6
# Plot is used for Diabolique
# Plot is used for Courage Under Fire
# Plot is used for Mission: Impossible
# Plot is used for Moll Flanders
# Plot is used for Eddie
# Plot is used for August
# Plot is used for James and the Giant Peach
# Plot is used for Fear
# Plot is used for Faithful
# Plot is used for Mystery Science Theater 3000: The Movie
# Plot is used for Space Jam
# Plot is used for Windows
# Plot is used for It's My Party
# Plot is used for Country Life
# Plot is used for Operation Dumbo Drop
# Plot is used for Mrs. Winterbourne
# Plot is used for Solo
# Plot is used for The Substitute
# Plot is used for True Crime
# Plot is used for Butterfly Kiss
# Plot is used for Feeling Minnesota
# Plot is used for Angus
# Plot is used for Faces
# Plot is used for Boys
# Plot is used for The Quest
# Plot is used for Sunset Park
# Plot is used for Mulholland Falls
# Plot is used for The Truth About Cats & Dogs
# Plot is used for Oliver & Company
# Plot is used for Celtic Pride
# Plot is used for Flipper
# Plot is used for Captives
# Plot is used for Dead Man
# Plot is used for Multiplicity
# Plot is used for The Craft
# Plot is used for The Great White Hype
# Plot is used for Last Dance
# Plot is used for Heaven's Prisoners
# Plot is used for Original Gangstas
# Plot is used for The Rock
# Plot is used for Getting Away with Murder
# Plot is used for Twister
# Plot is used for Barb Wire
# Plot is used for Thinner
# Plot is used for Spy Hard
# Plot is used for Force of Evil
# Plot is used for The Stupids
# Plot is used for The Arrival
# Plot is used for The Man from Down Under
# Plot is used for Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb
# Plot is used for Careful
# Plot is used for Gold Diggers: The Secret of Bear Mountain
# Plot is used for Kim
# Plot is used for Stalingrad
# Plot is used for The Phantom
# Plot is used for Striptease
# Plot is used for Heavy
# Plot is used for Jack
# Plot is used for I Shot Andy Warhol
# Plot is used for Trainspotting
# Plot is used for Independence Day
# Plot is used for Stealing Beauty
# Plot is used for The Fan
# Plot is used for The Hunchback of Notre Dame
# Plot is used for The Cable Guy
# Plot is used for Kingpin
# Plot is used for Eraser
# Plot is used for The Nutty Professor
# Plot is used for A Very Natural Thing
# Plot is used for Daylight
# Plot is used for The Frighteners
# Plot is used for Lone Star
# Plot is used for Harriet the Spy
# Plot is used for Phenomenon
# Plot is used for Walking and Talking
# Plot is used for She's the One
# Plot is used for A Time to Kill
# Plot is used for Alaska
# Plot is used for Fled
# Plot is used for Kazaam
# Plot is used for Larger Than Life
# Plot is used for Two Deaths
# Plot is used for A Very Brady Sequel
# Plot is used for The Adventures of Pinocchio
# Plot is used for Joe's Apartment
# Plot is used for The First Wives Club
# Plot is used for Stonewall
# Plot is used for Ransom
# Plot is used for High School High
# Plot is used for Phat Beach
# Plot is used for Foxfire
# Plot is used for Chain Reaction
# Plot is used for Matilda
# Plot is used for Emma
# Plot is used for The Crow: City of Angels
# Plot is used for House Arrest
# Plot is used for Flirt
# Plot is used for The Spitfire Grill
# Plot is used for Escape from L.A.
# Plot is used for Basquiat
# Plot is used for Tin Cup
# Plot is used for The Godfather
# Plot is used for Bound
# Plot is used for Carpool
# Plot is used for Death in Brunswick
# Plot is used for Kansas City
# Plot is used for Gone Fishin'
# Plot is used for Killer: A Journal of Murder
# Plot is used for Nothing to Lose
# Plot is used for Girls Town
# Plot is used for The Relic
# Plot is used for The Island of Dr. Moreau
# Plot is used for First Kid
# Plot is used for The Trigger Effect
# Plot is used for Bulletproof
# Plot is used for The Land Before Time III: The Time of the Great Giving
# Plot is used for Halloween: The Curse of Michael Myers
# Plot is used for Twelfth Night
# Plot is used for Mother Night
# Plot is used for For Whom the Bell Tolls
# Plot is used for The Philadelphia Story
# Plot is used for Singin' in the Rain
# Plot is used for An American in Paris
# Plot is used for Funny Face
# Plot is used for Breakfast at Tiffany's
# Plot is used for Vertigo
# Plot is used for Rear Window
# Plot is used for It Happened One Night
# Plot is used for Gaslight
# Plot is used for The Gay Divorcee
# Plot is used for North by Northwest
# Plot is used for The Apartment
# Plot is used for Some Like It Hot
# Plot is used for Charade
# Plot is used for Casablanca
# Plot is used for The Maltese Falcon
# Plot is used for My Fair Lady
# Plot is used for Sabrina
# Plot is used for Roman Holiday
# Plot is used for The Little Princess
# Plot is used for Meet Me in St. Louis
# Plot is used for The Wizard of Oz
# Plot is used for Gone with the Wind
# Plot is used for My Favorite Year
# Plot is used for Sunset Boulevard
# Plot is used for Citizen Kane
# Plot is used for 2001: A Space Odyssey
# Plot is used for Golden Earrings
# Plot is used for All About Eve
# Plot is used for The Women
# Plot is used for Rebecca
# Plot is used for Foreign Correspondent
# Plot is used for Notorious
# Plot is used for Spellbound
# Plot is used for An Affair to Remember
# Plot is used for To Catch a Thief
# Plot is used for Father of the Bride
# Plot is used for The Band Wagon
# Plot is used for Ninotchka
# Plot is used for Love in the Afternoon
# Plot is used for Gigi
# Plot is used for The Reluctant Debutante
# Plot is used for The Adventures of Robin Hood
# Plot is used for The Mark of Zorro
# Plot is used for Laura
# Plot is used for The Ghost and Mrs. Muir
# Plot is used for Lost Horizon
# Plot is used for Top Hat
# Plot is used for To Be or Not to Be
# Plot is used for My Man Godfrey
# Plot is used for Giant
# Plot is used for East of Eden
# Plot is used for The Thin Man
# Plot is used for His Girl Friday
# Plot is used for Around the World in Eighty Days
# Plot is used for It's a Wonderful Life
# Plot is used for Mr. Smith Goes to Washington
# Plot is used for Bringing Up Baby
# Plot is used for Penny Serenade
# Plot is used for Lady of Burlesque
# Plot is used for Of Human Bondage
# Plot is used for Angel on My Shoulder
# Plot is used for Little Lord Fauntleroy
# Plot is used for They Made Me a Criminal
# Plot is used for The Inspector General
# Plot is used for Angel and the Badman
# Plot is used for The 39 Steps
# Plot is used for A Walk in the Sun
# Plot is used for The Outlaw
# Plot is used for Night of the Living Dead
# Plot is used for The African Queen
# Plot is used for Beat the Devil
# Plot is used for Cat on a Hot Tin Roof
# Plot is used for The Last Time I Saw Paris
# Plot is used for Meet John Doe
# Plot is used for Algiers
# Plot is used for A Farewell to Arms
# Plot is used for Nothing Personal
# Plot is used for Dangerous Ground
# Plot is used for Picnic
# Plot is used for The Pompatus of Love
# Plot is used for Fly Away Home
# Plot is used for Bliss
# Plot is used for Grace of My Heart
# Plot is used for Maximum Risk
# Plot is used for Michael Collins
# Plot is used for The Rich Man's Wife
# Plot is used for Infinity
# Plot is used for Big Night
# Plot is used for Last Man Standing
# Plot is used for Caught
# Plot is used for Set It Off
# Plot is used for 2 Days in the Valley
# Plot is used for Curdled
# Plot is used for Extreme Measures
# Plot is used for The Glimmer Man
# Plot is used for D3: The Mighty Ducks
# Plot is used for The Chamber
# Plot is used for The Apple Dumpling Gang
# Plot is used for Davy Crockett, King of the Wild Frontier
# Plot is used for The Love Bug
# Plot is used for Herbie Rides Again
# Plot is used for Old Yeller
# Plot is used for The Parent Trap
# Plot is used for Pollyanna
# Plot is used for Homeward Bound: The Incredible Journey
# Plot is used for The Shaggy Dog
# Plot is used for Swiss Family Robinson
# Plot is used for That Darn Cat!
# Plot is used for 20,000 Leagues Under the Sea
# Plot is used for Cool Runnings
# Plot is used for Angels in the Outfield
# Plot is used for Cinderella
# Plot is used for The Three Caballeros
# Plot is used for The Sword in the Stone
# Plot is used for So Dear to My Heart
# Plot is used for Robin Hood: Prince of Thieves
# Plot is used for Mary Poppins
# Plot is used for Dumbo
# Plot is used for Pete's Dragon
# Plot is used for Bedknobs and Broomsticks
# Plot is used for Alice in Wonderland
# Plot is used for The Fox and the Hound
# Plot is used for Freeway
# Plot is used for The Sound of Music
# Plot is used for Die Hard
# Plot is used for The Lawnmower Man
# Plot is used for Unhook the Stars
# Plot is used for Secrets & Lies
# Plot is used for That Thing You Do!
# Plot is used for To Gillian on Her 37th Birthday
# Plot is used for Surviving Picasso
# Plot is used for Love Is All There Is
# Plot is used for Beautiful Thing
# Plot is used for The Long Kiss Goodnight
# Plot is used for The Ghost and the Darkness
# Plot is used for Trees Lounge
# Plot is used for Get on the Bus
# Plot is used for Shadow Conspiracy
# Plot is used for Jude
# Plot is used for Everyone Says I Love You
# Plot is used for Romeo + Juliet
# Plot is used for Swingers
# Plot is used for Sleepers
# Plot is used for The Sunchaser
# Plot is used for Johns
# Plot is used for Aladdin and the King of Thieves
# Plot is used for The Woman in Question
# Plot is used for Shall We Dance
# Plot is used for A Damsel in Distress
# Plot is used for Crossfire
# Plot is used for Murder, My Sweet
# Plot is used for Macao
# Plot is used for For the Moment
# Plot is used for Willy Wonka & the Chocolate Factory
# Plot is used for The Innocents
# Plot is used for Sleeper
# Plot is used for Bananas
# Plot is used for A Fish Called Wanda
# Plot is used for The Candidate
# Plot is used for The Great Race
# Plot is used for Bonnie and Clyde
# Plot is used for The Old Man and the Sea
# Plot is used for Dial M for Murder
# Plot is used for Madame Butterfly
# Plot is used for Dirty Dancing
# Plot is used for Reservoir Dogs
# Plot is used for Platoon
# Plot is used for Weekend at Bernie's
# Plot is used for Basic Instinct
# Plot is used for The Doors
# Plot is used for The Crying Game
# Plot is used for Glengarry Glen Ross
# Plot is used for Sophie's Choice
# Plot is used for E.T. the Extra-Terrestrial
# Plot is used for A Christmas Carol
# Plot is used for Days of Thunder
# Plot is used for Top Gun
# Plot is used for Rebel Without a Cause
# Plot is used for A Streetcar Named Desire
# Plot is used for Children of the Corn IV: The Gathering
# Plot is used for The Associate
# Plot is used for The Funeral
# Plot is used for The People vs. Larry Flynt
# Plot is used for On Golden Pond
# Plot is used for The Return of the Pink Panther
# Plot is used for Drop Dead Fred
# Plot is used for The Abyss
# Plot is used for The Fog
# Plot is used for Escape from New York
# Plot is used for The Howling
# Plot is used for Private Benjamin
# Plot is used for Monty Python and the Holy Grail
# Plot is used for The Wrong Trousers
# Plot is used for Faust
# Plot is used for He Walked by Night
# Plot is used for Raw Deal
# Plot is used for T-Men
# Plot is used for The Ruling Class
# Plot is used for Dear God
# Plot is used for Bad Moon
# Plot is used for Best of the Best 3: No Turning Back
# Plot is used for Bob Roberts
# Plot is used for The Cook, the Thief, His Wife & Her Lover
# Plot is used for Enchanted April
# Plot is used for Paths of Glory
# Plot is used for The Grifters
# Plot is used for Hear My Song
# Plot is used for The English Patient
# Plot is used for Sex, Lies, and Videotape
# Plot is used for Passion Fish
# Plot is used for Strictly Ballroom
# Plot is used for Madonna: Truth or Dare
# Plot is used for One Flew Over the Cuckoo's Nest
# Plot is used for Up in Smoke
# Plot is used for The Empire Strikes Back
# Plot is used for The Princess Bride
# Plot is used for Raiders of the Lost Ark
# Plot is used for Brazil
# Plot is used for Aliens
# Plot is used for 12 Angry Men
# Plot is used for Lawrence of Arabia
# Plot is used for A Clockwork Orange
# Plot is used for To Kill a Mockingbird
# Plot is used for Apocalypse Now
# Plot is used for Return of the Jedi
# Plot is used for The Third Man
# Plot is used for Alien
# Plot is used for Psycho
# Plot is used for Full Metal Jacket
# Plot is used for Henry V
# Plot is used for Amadeus
# Plot is used for The Quiet Man
# Plot is used for Once Upon a Time in America
# Plot is used for Raging Bull
# Plot is used for Annie Hall
# Plot is used for The Right Stuff
# Plot is used for The Sting
# Plot is used for Harold and Maude
# Plot is used for Trust
# Plot is used for Local Hero
# Plot is used for The Terminator
# Plot is used for Glory
# Plot is used for Rosencrantz & Guildenstern Are Dead
# Plot is used for Manhattan
# Plot is used for Miller's Crossing
# Plot is used for Dead Poets Society
# Plot is used for The Graduate
# Plot is used for Touch of Evil
# Plot is used for The Bridge on the River Kwai
# Plot is used for Chinatown
# Plot is used for The Day the Earth Stood Still
# Plot is used for The Treasure of the Sierra Madre
# Plot is used for Duck Soup
# Plot is used for The Shining
# Plot is used for Stand by Me
# Plot is used for M
# Plot is used for Evil Dead II
# Plot is used for The Great Escape
# Plot is used for The Deer Hunter
# Plot is used for Groundhog Day
# Plot is used for Unforgiven
# Plot is used for The Manchurian Candidate
# Plot is used for Arsenic and Old Lace
# Plot is used for Back to the Future
# Plot is used for Fried Green Tomatoes
# Plot is used for Patton
# Plot is used for Down by Law
# Plot is used for Highlander
# Plot is used for Cool Hand Luke
# Plot is used for Cyrano de Bergerac
# Plot is used for Young Frankenstein
# Plot is used for Night on Earth
# Plot is used for The Great Dictator
# Plot is used for Fantasia
# Plot is used for High Noon
# Plot is used for The Big Sleep
# Plot is used for Heathers
# Plot is used for Somewhere in Time
# Plot is used for Ben-Hur
# Plot is used for This Is Spinal Tap
# Plot is used for Some Kind of Wonderful
# Plot is used for Indiana Jones and the Last Crusade
# Plot is used for Being There
# Plot is used for Gandhi
# Plot is used for The Unbearable Lightness of Being
# Plot is used for A Room with a View
# Plot is used for Real Genius
# Plot is used for The Killing Fields
# Plot is used for Forbidden Planet
# Plot is used for Field of Dreams
# Plot is used for The Man Who Would Be King
# Plot is used for Butch Cassidy and the Sundance Kid
# Plot is used for Paris, Texas
# Plot is used for When Harry Met Sally...
# Plot is used for Parallel Sons
# Plot is used for Santa with Muscles
# Plot is used for I'm Not Rappaport
# Plot is used for Blue Juice
# Plot is used for An American Werewolf in London
# Plot is used for Amityville 3-D
# Plot is used for Amityville II: The Possession
# Plot is used for The Amityville Horror
# Plot is used for April Fool's Day
# Plot is used for Audrey Rose
# Plot is used for The Believers
# Plot is used for The Birds
# Plot is used for The Blob
# Plot is used for Body Parts
# Plot is used for The Body Snatcher
# Plot is used for Dracula
# Plot is used for Bride of Frankenstein
# Plot is used for Burnt Offerings
# Plot is used for Candyman
# Plot is used for Cape Fear
# Plot is used for Cape Fear
# Plot is used for Carrie
# Plot is used for Cat People
# Plot is used for A Nightmare on Elm Street
# Plot is used for The Omen
# Plot is used for Blood and Wine
# Plot is used for Albino Alligator
# Plot is used for The Mirror Has Two Faces
# Plot is used for Breaking the Waves
# Plot is used for Star Trek: First Contact
# Plot is used for Shine
# Plot is used for Sling Blade
# Plot is used for Jingle All the Way
# Plot is used for The Preacher's Wife
# Plot is used for The Crucible
# Plot is used for 101 Dalmatians
# Plot is used for Die Hard 2
# Plot is used for Star Trek: The Motion Picture
# Plot is used for Star Trek VI: The Undiscovered Country
# Plot is used for Star Trek V: The Final Frontier
# Plot is used for Star Trek II: The Wrath of Khan
# Plot is used for Star Trek III: The Search for Spock
# Plot is used for Star Trek IV: The Voyage Home
# Plot is used for Batman Returns
# Plot is used for Young Guns
# Plot is used for Young Guns II
# Plot is used for Grease
# Plot is used for Grease 2
# Plot is used for Marked for Death
# Plot is used for Adrenalin: Fear the Rush
# Plot is used for Under Siege
# Plot is used for Terror in a Texas Town
# Plot is used for Jaws
# Plot is used for Jaws 2
# Plot is used for Jaws 3-D
# Plot is used for My Fellow Americans
# Plot is used for Mars Attacks!
# Plot is used for Citizen Ruth
# Plot is used for Jerry Maguire
# Plot is used for Raising Arizona
# Plot is used for Tin Men
# Plot is used for Sneakers
# Plot is used for Bastard Out of Carolina
# Plot is used for In Love and War
# Plot is used for Marvin's Room
# Plot is used for Ghosts of Mississippi
# Plot is used for Night Falls on Manhattan
# Plot is used for Beavis and Butt-Head Do America
# Plot is used for Scream
# Plot is used for The Last of the Mohicans
# Plot is used for Michael
# Plot is used for The Evening Star
# Plot is used for The Whole Wide World
# Plot is used for Mother
# Plot is used for Evita
# Plot is used for The Portrait of a Lady
# Plot is used for Walkabout
# Plot is used for Murder at 1600
# Plot is used for Fierce Creatures
# Plot is used for Turbulence
# Plot is used for Angel Baby
# Plot is used for Underworld
# Plot is used for Beverly Hills Ninja
# Plot is used for Metro
# Plot is used for The Cement Garden
# Plot is used for Dante's Peak
# Plot is used for Meet Wally Sparks
# Plot is used for Amos & Andrew
# Plot is used for Benny & Joon
# Plot is used for Prefontaine
# Plot is used for McHale's Navy
# Plot is used for Gridlock'd
# Plot is used for Waiting for Guffman
# Plot is used for The Beautician and the Beast
# Plot is used for Fools Rush In
# Plot is used for Touch
# Plot is used for Absolute Power
# Plot is used for That Darn Cat
# Plot is used for Vegas Vacation
# Plot is used for That Old Feeling
# Plot is used for Lost Highway
# Plot is used for Rosewood
# Plot is used for Donnie Brasco
# Plot is used for Booty Call
# Plot is used for City of Industry
# Plot is used for Jungle 2 Jungle
# Plot is used for Private Parts
# Plot is used for The Saint
# Plot is used for The Van
# Plot is used for Crash
# Plot is used for Liar Liar
# Plot is used for The Quiet Room
# Plot is used for Selena
# Plot is used for Cats Don't Dance
# Plot is used for Love and Other Catastrophes
# Plot is used for Turbo: A Power Rangers Movie
# Plot is used for Anna Karenina
# Plot is used for Double Team
# Plot is used for Inventing the Abbotts
# Plot is used for Anaconda
# Plot is used for Grosse Pointe Blank
# Plot is used for Keys to Tulsa
# Plot is used for Kissed
# Plot is used for 8 Heads in a Duffel Bag
# Plot is used for All Over Me
# Plot is used for Romy and Michele's High School Reunion
# Plot is used for Volcano
# Plot is used for Children of the Revolution
# Plot is used for Austin Powers: International Man of Mystery
# Plot is used for Breakdown
# Plot is used for Broken English
# Plot is used for Truth or Consequences, N.M.
# Plot is used for Warriors of Virtue
# Plot is used for Fathers' Day
# Plot is used for The Fifth Element
# Plot is used for Nowhere
# Plot is used for Sprung
# Plot is used for The Second Jungle Book: Mowgli & Baloo
# Plot is used for Twin Town
# Plot is used for Addicted to Love
# Plot is used for Brassed Off
# Plot is used for The Lost World: Jurassic Park
# Plot is used for Shiloh
# Plot is used for The War at Home
# Plot is used for Rough Magic
# Plot is used for Trial and Error
# Plot is used for Buddy
# Plot is used for Con Air
# Plot is used for Late Bloomers
# Plot is used for The Pillow Book
# Plot is used for Speed 2: Cruise Control
# Plot is used for Dream with the Fishes
# Plot is used for The Last Time I Committed Suicide
# Plot is used for My Best Friend's Wedding
# Plot is used for Tetsuo II: Body Hammer
# Plot is used for Face/Off
# Plot is used for Fall
# Plot is used for Men in Black
# Plot is used for Out to Sea
# Plot is used for Wild America
# Plot is used for A Simple Wish
# Plot is used for Contact
# Plot is used for G.I. Jane
# Plot is used for Conan the Barbarian
# Plot is used for George of the Jungle
# Plot is used for Cop Land
# Plot is used for Event Horizon
# Plot is used for Spawn
# Plot is used for Air Bud
# Plot is used for Picture Perfect
# Plot is used for In the Company of Men
# Plot is used for Free Willy 3: The Rescue
# Plot is used for Career Girls
# Plot is used for Conspiracy Theory
# Plot is used for Desperate Measures
# Plot is used for Steel
# Plot is used for She's So Lovely
# Plot is used for Hoodlum
# Plot is used for Mimic
# Plot is used for Money Talks
# Plot is used for Excess Baggage
# Plot is used for Kull the Conqueror
# Plot is used for Air Force One
# Plot is used for One Eight Seven
# Plot is used for The Hunt for Red October
# Plot is used for My Own Private Idaho
# Plot is used for In & Out
# Plot is used for The Edge
# Plot is used for The Peacemaker
# Plot is used for L.A. Confidential
# Plot is used for Seven Years in Tibet
# Plot is used for Kiss the Girls
# Plot is used for Soul Food
# Plot is used for Wishmaster
# Plot is used for A Thousand Acres
# Plot is used for The Game
# Plot is used for Fire Down Below
# Plot is used for U Turn
# Plot is used for The Matchmaker
# Plot is used for The Assignment
# Plot is used for A Smile Like Yours
# Plot is used for The Ice Storm
# Plot is used for Chasing Amy
# Plot is used for The Full Monty
# Plot is used for Indian Summer
# Plot is used for Mrs Brown
# Plot is used for I Know What You Did Last Summer
# Plot is used for The Devil's Advocate
# Plot is used for RocketMan
# Plot is used for Playing God
# Plot is used for The House of Yes
# Plot is used for Washington Square
# Plot is used for Gattaca
# Plot is used for FairyTale: A True Story
# Plot is used for Phantoms
# Plot is used for Swept from the Sea
# Plot is used for Wonderland
# Plot is used for A Life Less Ordinary
# Plot is used for Hurricane Streets
# Plot is used for Eve's Bayou
# Plot is used for Switchback
# Plot is used for Gang Related
# Plot is used for Stripes
# Plot is used for Bean
# Plot is used for Hugo Pool
# Plot is used for Mad City
# Plot is used for One Night Stand
# Plot is used for Welcome to Sarajevo
# Plot is used for The Rainmaker
# Plot is used for Boogie Nights
# Plot is used for Witness
# Plot is used for Starship Troopers
# Plot is used for The Joy Luck Club
# Plot is used for Chairman of the Board
# Plot is used for Sliding Doors
# Plot is used for Mortal Kombat: Annihilation
# Plot is used for The Truman Show
# Plot is used for The Wings of the Dove
# Plot is used for I Love You, I Love You Not
# Plot is used for Red Corner
# Plot is used for The Jackal
# Plot is used for Anastasia
# Plot is used for The Man Who Knew Too Little
# Plot is used for Amistad
# Plot is used for The Apostle
# Plot is used for Bent
# Plot is used for Les Boys
# Plot is used for The Butcher Boy
# Plot is used for Deconstructing Harry
# Plot is used for Flubber
# Plot is used for For Richer or Poorer
# Plot is used for Good Will Hunting
# Plot is used for Home Alone 3
# Plot is used for MouseHunt
# Plot is used for Office Killer
# Plot is used for Scream 2
# Plot is used for Stranger in the House
# Plot is used for The Sweet Hereafter
# Plot is used for Titanic
# Plot is used for Tomorrow Never Dies
# Plot is used for Twisted
# Plot is used for The Postman
# Plot is used for The Horse Whisperer
# Plot is used for The Winter Guest
# Plot is used for Jackie Brown
# Plot is used for Kundun
# Plot is used for The Big Lebowski
# Plot is used for Afterglow
# Plot is used for Caught Up
# Plot is used for Firestorm
# Plot is used for Senseless
# Plot is used for Wag the Dog
# Plot is used for Dark City
# Plot is used for Star Kid
# Plot is used for Hard Rain
# Plot is used for Half Baked
# Plot is used for Fallen
# Plot is used for Shooting Fish
# Plot is used for Spice World
# Plot is used for Deep Rising
# Plot is used for Music from Another Room
# Plot is used for The Replacement Killers
# Plot is used for B. Monkey
# Plot is used for The Night Flier
# Plot is used for Blues Brothers 2000
# Plot is used for Tokyo Fist
# Plot is used for Ride
# Plot is used for The Wedding Singer
# Plot is used for Sphere
# Plot is used for Little City
# Plot is used for Palmetto
# Plot is used for As Good as It Gets
# Plot is used for King of New York
# Plot is used for Twilight
# Plot is used for U.S. Marshals
# Plot is used for Welcome to Woop Woop
# Plot is used for Love and Death on Long Island
# Plot is used for Everest
# Plot is used for Hush
# Plot is used for Suicide Kings
# Plot is used for The Man in the Iron Mask
# Plot is used for The Newton Boys
# Plot is used for Wild Things
# Plot is used for Primary Colors
# Plot is used for Wide Awake
# Plot is used for A Price Above Rubies
# Plot is used for Eden
# Plot is used for No Looking Back
# Plot is used for The Proposition
# Plot is used for The Object of My Affection
# Plot is used for Meet the Deedles
# Plot is used for The Players Club
# Plot is used for Chinese Box
# Plot is used for Heaven's Burning
# Plot is used for Mercury Rising
# Plot is used for The Spanish Prisoner
# Plot is used for City of Angels
# Plot is used for The Last Days of Disco
# Plot is used for The Odd Couple II
# Plot is used for My Giant
# Plot is used for He Got Game
# Plot is used for The Gingerbread Man
# Plot is used for Slappy and the Stinkers
# Plot is used for Zero Effect
# Plot is used for Nil by Mouth
# Plot is used for The Borrowers
# Plot is used for Prince Valiant
# Plot is used for Krippendorf's Tribe
# Plot is used for Species II
# Plot is used for Major League: Back to the Minors
# Plot is used for Sour Grapes
# Plot is used for The Big Hit
# Plot is used for Tarzan and the Lost City
# Plot is used for Black Dog
# Plot is used for Les Misérables
# Plot is used for Clockwatchers
# Plot is used for Deep Impact
# Plot is used for Woo
# Plot is used for The Hanging Garden
# Plot is used for Lawn Dogs
# Plot is used for Quest for Camelot
# Plot is used for Godzilla
# Plot is used for Bulworth
# Plot is used for Fear and Loathing in Las Vegas
# Plot is used for The Opposite of Sex
# Plot is used for I Got the Hook Up
# Plot is used for Almost Heroes
# Plot is used for Hope Floats
# Plot is used for Insomnia
# Plot is used for A Perfect Murder
# Plot is used for Six Days Seven Nights
# Plot is used for Can't Hardly Wait
# Plot is used for Cousin Bette
# Plot is used for The Land Girls
# Plot is used for Henry Fool
# Plot is used for Mulan
# Plot is used for Doctor Dolittle
# Plot is used for Out of Sight
# Plot is used for Picnic at Hanging Rock
# Plot is used for Smoke Signals
# Plot is used for Buffalo '66
# Plot is used for Armageddon
# Plot is used for Lethal Weapon 4
# Plot is used for Madeline
# Plot is used for Small Soldiers
# Plot is used for Pi
# Plot is used for There's Something About Mary
# Plot is used for Plan 9 from Outer Space
# Plot is used for Wings
# Plot is used for The Broadway Melody
# Plot is used for All Quiet on the Western Front
# Plot is used for Cimarron
# Plot is used for Grand Hotel
# Plot is used for Cavalcade
# Plot is used for Mutiny on the Bounty
# Plot is used for The Great Ziegfeld
# Plot is used for How Green Was My Valley
# Plot is used for Mrs. Miniver
# Plot is used for Going My Way
# Plot is used for The Lost Weekend
# Plot is used for The Best Years of Our Lives
# Plot is used for Gentleman's Agreement
# Plot is used for All the King's Men
# Plot is used for The Greatest Show on Earth
# Plot is used for From Here to Eternity
# Plot is used for On the Waterfront
# Plot is used for Marty
# Plot is used for West Side Story
# Plot is used for Tom Jones
# Plot is used for A Man for All Seasons
# Plot is used for In the Heat of the Night
# Plot is used for Midnight Cowboy
# Plot is used for The French Connection
# Plot is used for Rocky
# Plot is used for Kramer vs. Kramer
# Plot is used for Ordinary People
# Plot is used for Chariots of Fire
# Plot is used for Terms of Endearment
# Plot is used for Out of Africa
# Plot is used for The Last Emperor
# Plot is used for Rain Man
# Plot is used for Driving Miss Daisy
# Plot is used for Take the Money and Run
# Plot is used for Klute
# Plot is used for Repo Man
# Plot is used for Metropolitan
# Plot is used for Labyrinth
# Plot is used for The Breakfast Club
# Plot is used for A Nightmare on Elm Street 3: Dream Warriors
# Plot is used for A Nightmare on Elm Street 4: The Dream Master
# Plot is used for A Nightmare on Elm Street 5: The Dream Child
# Plot is used for Freddy's Dead: The Final Nightmare
# Plot is used for Friday the 13th
# Plot is used for Friday the 13th Part 2
# Plot is used for Friday the 13th Part III
# Plot is used for Friday the 13th: The Final Chapter
# Plot is used for Friday the 13th: A New Beginning
# Plot is used for Friday the 13th Part VI: Jason Lives
# Plot is used for Friday the 13th Part VII: The New Blood
# Plot is used for Friday the 13th Part VIII: Jason Takes Manhattan
# Plot is used for Halloween
# Plot is used for Halloween II
# Plot is used for Halloween III: Season of the Witch
# Plot is used for Halloween 4: The Return of Michael Myers
# Plot is used for Halloween 5: The Revenge of Michael Myers
# Plot is used for Prom Night
# Plot is used for Hello Mary Lou: Prom Night II
# Plot is used for Prom Night III: The Last Kiss
# Plot is used for Prom Night IV: Deliver Us from Evil
# Plot is used for Child's Play
# Plot is used for Child's Play 2
# Plot is used for Child's Play 3
# Plot is used for Poltergeist
# Plot is used for Poltergeist II: The Other Side
# Plot is used for Poltergeist III
# Plot is used for The Exorcist
# Plot is used for Exorcist II: The Heretic
# Plot is used for The Exorcist III
# Plot is used for Lethal Weapon
# Plot is used for Lethal Weapon 2
# Plot is used for Lethal Weapon 3
# Plot is used for Gremlins
# Plot is used for Gremlins 2: The New Batch
# Plot is used for The Mask of Zorro
# Plot is used for This World, Then the Fireworks
# Plot is used for Soylent Green
# Plot is used for Metropolis
# Plot is used for Back to the Future Part II
# Plot is used for Back to the Future Part III
# Plot is used for The Poseidon Adventure
# Plot is used for Freaky Friday
# Plot is used for The Absent-Minded Professor
# Plot is used for The Apple Dumpling Gang Rides Again
# Plot is used for Babes in Toyland
# Plot is used for Bambi
# Plot is used for Dangerous Liaisons
# Plot is used for Dune
# Plot is used for The Last Temptation of Christ
# Plot is used for The Rapture
# Plot is used for Lolita
# Plot is used for Disturbing Behavior
# Plot is used for Jane Austen's Mafia!
# Plot is used for Saving Private Ryan
# Plot is used for Billy's Hollywood Screen Kiss
# Plot is used for The Million Dollar Duck
# Plot is used for The Barefoot Executive
# Plot is used for The Black Hole
# Plot is used for Blackbeard's Ghost
# Plot is used for Blank Check
# Plot is used for Candleshoe
# Plot is used for The Cat from Outer Space
# Plot is used for Cheetah
# Plot is used for The Computer Wore Tennis Shoes
# Plot is used for Condorman
# Plot is used for D2: The Mighty Ducks
# Plot is used for Darby O'Gill and the Little People
# Plot is used for The Devil and Max Devlin
# Plot is used for A Far Off Place
# Plot is used for Flight of the Navigator
# Plot is used for The Gnome-Mobile
# Plot is used for The Great Mouse Detective
# Plot is used for The Happiest Millionaire
# Plot is used for Herbie Goes Bananas
# Plot is used for Hocus Pocus
# Plot is used for Honey, I Shrunk the Kids
# Plot is used for In Search of the Castaways
# Plot is used for The Incredible Journey
# Plot is used for The Negotiator
# Plot is used for The Parent Trap
# Plot is used for BASEketball
# Plot is used for Out of the Past
# Plot is used for Doctor Zhivago
# Plot is used for The Trip to Bountiful
# Plot is used for Tender Mercies
# Plot is used for The 'Burbs
# Plot is used for Fandango
# Plot is used for Blue Velvet
# Plot is used for The Journey of Natty Gann
# Plot is used for The Jungle Book
# Plot is used for Lady and the Tramp
# Plot is used for The Little Mermaid
# Plot is used for The Mighty Ducks
# Plot is used for The Muppet Christmas Carol
# Plot is used for Newsies
# Plot is used for One Hundred and One Dalmatians
# Plot is used for One Magic Christmas
# Plot is used for Peter Pan
# Plot is used for Popeye
# Plot is used for The Rescuers Down Under
# Plot is used for The Rescuers
# Plot is used for Return from Witch Mountain
# Plot is used for Return to Oz
# Plot is used for The Rocketeer
# Plot is used for The Shaggy D.A.
# Plot is used for Sleeping Beauty
# Plot is used for Something Wicked This Way Comes
# Plot is used for Son of Flubber
# Plot is used for Song of the South
# Plot is used for Splash
# Plot is used for Squanto: A Warrior's Tale
# Plot is used for Tex
# Plot is used for Tron
# Plot is used for Swing Kids
# Plot is used for L.A. Story
# Plot is used for The Jerk
# Plot is used for Dead Men Don't Wear Plaid
# Plot is used for The Man with Two Brains
# Plot is used for Grand Canyon
# Plot is used for The Outsiders
# Plot is used for Indiana Jones and the Temple of Doom
# Plot is used for The Lord of the Rings
# Plot is used for The Dead Zone
# Plot is used for Maximum Overdrive
# Plot is used for Needful Things
# Plot is used for Cujo
# Plot is used for Children of the Corn
# Plot is used for All Dogs Go to Heaven
# Plot is used for The Addams Family
# Plot is used for Snake Eyes
# Plot is used for Atlantic City
# Plot is used for Who's Afraid of Virginia Woolf?
# Plot is used for Adventures in Babysitting
# Plot is used for Weird Science
# Plot is used for Doctor Dolittle
# Plot is used for The Nutty Professor
# Plot is used for Charlotte's Web
# Plot is used for Watership Down
# Plot is used for The Secret of NIMH
# Plot is used for The Dark Crystal
# Plot is used for An American Tail: Fievel Goes West
# Plot is used for Legend
# Plot is used for Sixteen Candles
# Plot is used for Pretty in Pink
# Plot is used for St. Elmo's Fire
# Plot is used for House
# Plot is used for House II: The Second Story
# Plot is used for Air Bud: Golden Receiver
# Plot is used for How Stella Got Her Groove Back
# Plot is used for Slums of Beverly Hills
# Plot is used for Henry: Portrait of a Serial Killer
# Plot is used for Rosemary's Baby
# Plot is used for Surf Nazis Must Die
# Plot is used for Your Friends & Neighbors
# Plot is used for Return to Paradise
# Plot is used for Blade
# Plot is used for Dance with Me
# Plot is used for Dead Man on Campus
# Plot is used for Wrongfully Accused
# Plot is used for Next Stop Wonderland
# Plot is used for The Navigator: A Medieval Odyssey
# Plot is used for Beetlejuice
# Plot is used for Déjà Vu
# Plot is used for Rope
# Plot is used for Family Plot
# Plot is used for Frenzy
# ...
# Plot is used for Sounder
# Plot is used for Suburban Mayhem
# Plot is used for The Battle of Midway
# Plot is used for The Bespoke Overcoat
# Plot is used for Goin' to Town
# Plot is used for Screamers
# Plot is used for The Cheaters
# Plot is used for The Halliday Brand
# Plot is used for When You're in Love
# Plot is used for Risk
# Plot is used for Kiki
# Plot is used for Trapped
# Plot is used for The Thirteenth Guest
# Plot is used for Just the Way You Are
# Plot is used for From Hell to Texas
# Plot is used for Diplomatic Courier
# Plot is used for Rawhide
# Plot is used for Whiplash
# Plot is used for The Optimists of Nine Elms
# Plot is used for Angel's Dance
# Plot is used for Strangers in the Night
# Plot is used for A United Kingdom
# Plot is used for The Secret Garden
# Plot is used for Crack in the World
# Plot is used for Below Utopia
# Plot is used for Bonobo
# Plot is used for Escape
# Plot is used for Iris
# Plot is used for The Boss
# Plot is used for Forever Female
# Plot is used for Hunted
# Plot is used for Cottage to Let
# Plot is used for Young Man of Manhattan
# Plot is used for Finishing School
# Plot is used for Twenty Million Sweethearts
# Plot is used for Inch'Allah
# Plot is used for Sour Grapes
# Plot is used for The Vengeance of She
# Plot is used for Jackie
# Plot is used for The Werewolf of Washington
# Plot is used for Logan
# Plot is used for They Knew What They Wanted
# Plot is used for The Space Between Us
# Plot is used for Split
# Plot is used for Opening Night
# Plot is used for Underworld: Blood Wars
# Plot is used for Too Hot to Handle
# Plot is used for Bwakaw
# Plot is used for Hobgoblins
# Plot is used for Mandıra Filozofu
# Plot is used for Deal
# Plot is used for Serena
# Plot is used for Rear Window
# Plot is used for Money
# Plot is used for Army
# Plot is used for Show Girl in Hollywood
# Plot is used for The End
# Plot is used for The Great Wall
# Plot is used for This Land Is Mine
# Plot is used for This Beautiful Fantastic
# Plot is used for The Founder
# Plot is used for Pixels
# Plot is used for Sing
# Plot is used for The Bachelor
# Plot is used for Echo Park
# Plot is used for Alone in Berlin
# Plot is used for Kedi
# Plot is used for The Ugly Duckling
# Plot is used for Five
# Plot is used for Iron Man
# Plot is used for Pleasure Cruise
# Plot is used for Dr. Cabbie
# Plot is used for A Dog's Purpose
# Plot is used for Jump
# Plot is used for The Little Kidnappers
# Plot is used for Sahib Bibi Aur Ghulam
# Plot is used for Bailout at 43,000
# Plot is used for Collide
# Plot is used for Annie Oakley
# Plot is used for Gold
# Plot is used for The Little Hours
# Plot is used for Milk
# Plot is used for Shank
# Plot is used for Fist Fight
# Plot is used for Monster Trucks
# Plot is used for Sleepless
# Plot is used for A Cure for Wellness
# Plot is used for Playing Beatie Bow
# Plot is used for A Street Cat Named Bob
# Plot is used for xXx: Return of Xander Cage
# Plot is used for The Bye Bye Man
# Plot is used for The Lego Batman Movie
# Plot is used for When the Bough Breaks
# Plot is used for What's Opera, Doc?
# Plot is used for Bartleby
# Plot is used for The Phantom
# Plot is used for Silk
# Plot is used for I'm Not Ashamed
# Plot is used for Summer Love
# Plot is used for Lucky Girl
# Plot is used for Rings
# Plot is used for Special Delivery
# Plot is used for Gossip
# Plot is used for Fresh Hare
# Plot is used for The Black Sheep of Whitehall
# Plot is used for Munster, Go Home!
# Plot is used for The Crash
# Plot is used for John Wick: Chapter 2
# Plot is used for Get Out
# Plot is used for Logan
# Plot is used for Kong: Skull Island
# Plot is used for City of Tiny Lights
# Plot is used for T2 Trainspotting
# Plot is used for The Land Beyond the Sunset
# Plot is used for Before I Fall
# Plot is used for The Belko Experiment
# Plot is used for The Big Sick
# Plot is used for Ingrid Goes West
# Plot is used for I Don't Feel at Home in This World Anymore
# Plot is used for Chocolat
# Plot is used for George's Island
# Plot is used for King Arthur: Legend of the Sword
# Plot is used for 100 Streets
# Plot is used for Saturn 3
# Plot is used for For Love or Money
# Plot is used for Beauty and the Beast
# Plot is used for Man Without a Star
# Plot is used for The Black Torment
# Plot is used for Crosstrap
# Plot is used for Mughal-e-Azam
# Plot is used for Boo! A Madea Halloween
# Plot is used for Coco
# Plot is used for The Boss Baby
# Plot is used for Thank You for Your Service
# Plot is used for Call Me by Your Name
# Plot is used for Resident Evil: The Final Chapter
# Plot is used for iBoy
# Plot is used for Two Lovers and a Bear
# Plot is used for The Captive
# Plot is used for Catfight
# Plot is used for A Ghost Story
# Plot is used for Ghost in the Shell
# Plot is used for Private Property
# Plot is used for Maalik
# Plot is used for Lost in the Pacific
# Plot is used for XX
# Plot is used for Sadako vs. Kayako
# Plot is used for Ok Jaanu
# Plot is used for Fifty Shades Darker
# Plot is used for Wilson
# Plot is used for Don't Knock Twice
# Plot is used for Dishonored Lady
# Plot is used for Molly and Me
# Plot is used for Lavender
# Plot is used for Detour
# Plot is used for The Book of Love
# Plot is used for The Stranger
# Plot is used for Deadly Duo
# Plot is used for Behind Green Lights
# Plot is used for Fever Lake
# Plot is used for The Escape
# Plot is used for Youth in Oregon
# Plot is used for Song to Song
# Plot is used for American Fable
# Plot is used for God's Own Country
# Plot is used for Hostages
# Plot is used for Lovesong
# Plot is used for Offerings
# Plot is used for My Entire High School Sinking Into the Sea
# Plot is used for The Strange Woman
# Plot is used for The Man Who Cheated Himself
# Plot is used for Happy End
# Plot is used for Timecode
# Plot is used for Mean Dreams
# Plot is used for Donald Cried
# Plot is used for Their Finest
# Plot is used for Lady Macbeth
# Plot is used for Window Horses
# Plot is used for River
# Plot is used for The Assignment
# Plot is used for Fallen
# Plot is used for The Shack
# Plot is used for Life
# Plot is used for Foster
# Plot is used for Kaabil
# Plot is used for The Lost City of Z
# Plot is used for Sleight
# Plot is used for School Dance
# Plot is used for Power Rangers
# Plot is used for Alien: Covenant
# Plot is used for Free Fire
# Plot is used for The Prince and the Pauper
# Plot is used for The Amorous Prawn
# Plot is used for The Importance of Being Earnest
# Plot is used for The Yellow Rolls-Royce
# Plot is used for The Scapegoat
# Plot is used for Sleepaway Camp II: Unhappy Campers
# Plot is used for Penny Points to Paradise
# Plot is used for Rad
# Plot is used for Poodle Springs
# Plot is used for Gemini
# Plot is used for Junior
# Plot is used for Ma' Rosa
# Plot is used for Kill Squad
# Plot is used for Jason and the Argonauts
# Plot is used for The Stoned Age
# Plot is used for The Legend of Billie Jean
# Plot is used for Ali and Nino
# Plot is used for Thirst
# Plot is used for The Blue Butterfly
# Plot is used for Everyone's Going to Die
# Plot is used for The Last Word
# Plot is used for Aventure Malgache
# Plot is used for Table 19
# Plot is used for Going in Style
# Plot is used for Island in the Sky
# Plot is used for Red Nightmare
# Plot is used for Cleopatra
# Plot is used for Nayakan
# Plot is used for Swashbuckler
# Plot is used for Bitter Harvest
# Plot is used for Triple Crossed
# Plot is used for A Bullet for Pretty Boy
# Plot is used for Caprice
# Plot is used for Smurfs: The Lost Village
# Plot is used for The Discovery
# Plot is used for Viceroy's House
# Plot is used for The Zookeeper's Wife
# Plot is used for The Bed-Sitting Room
# Plot is used for Gifted
# Plot is used for 24
# Plot is used for Aftermath
# Plot is used for Beware! The Blob
# Plot is used for The Baker
# Plot is used for The Case for Christ
# Plot is used for Everything, Everything
# Plot is used for Diary of a Wimpy Kid: The Long Haul
# Plot is used for Baywatch
# Plot is used for Unforgettable
# Plot is used for Snatched
# Plot is used for The Mummy
# Plot is used for The Fate of the Furious
# Plot is used for Wild and Woolly
# Plot is used for Burning Sands
# Plot is used for Walking with the Enemy
# Plot is used for The Swan Princess Christmas
# Plot is used for Love on the Run
# Plot is used for Captain Underpants: The First Epic Movie
# Plot is used for It Comes at Night
# Plot is used for Megan Leavey
# Plot is used for My Cousin Rachel
# Plot is used for Cars 3
# Plot is used for The Covenant
# Plot is used for Horror Story
# Plot is used for Mini's First Time
# Plot is used for The Wonderful Wizard of Oz
# Plot is used for Shala
# Plot is used for The Book of Henry
# Plot is used for The Wall
# Plot is used for Without Evidence
# Plot is used for True Identity
# Plot is used for Girlfriends
# Plot is used for Tommy's Honour
# Plot is used for Boat
# Plot is used for Heavy Traffic
# Plot is used for You Can't Cheat an Honest Man
# Plot is used for Poppy
# Plot is used for Frankenweenie
# Plot is used for Beyond Skyline
# Plot is used for Mars et Avril
# Plot is used for How to Be a Latin Lover
# Plot is used for The Trip to Spain
# Plot is used for Malibu Express
# Plot is used for Guns
# Plot is used for Brigsby Bear
# Plot is used for Angels' Brigade
# Plot is used for Bear Island
# Plot is used for Ay Lav Yu
# Plot is used for Sultan
# Plot is used for The Trial
# Plot is used for Quo Vadis
# Plot is used for A Dark Song
# Plot is used for The Heart of the Game
# Plot is used for Revenge of the Creature
# Plot is used for Unlocked
# Plot is used for Perfect Harmony
# Plot is used for The Hidden II
# Plot is used for Bad Girl
# Plot is used for The Lovers
# Plot is used for Last Woman on Earth
# Plot is used for The Wizard of Gore
# Plot is used for Moontrap
# Plot is used for Munna Bhai M.B.B.S.
# Plot is used for Seizure
# Plot is used for Amityville: The Awakening
# Plot is used for The Beguiled
# Plot is used for Baby Driver
# Plot is used for Okja
# Plot is used for Rough Night
# Plot is used for Time Chasers
# Plot is used for I Accuse My Parents
# Plot is used for Mindhorn
# Plot is used for Phoenix
# Plot is used for In the Meantime, Darling
# Plot is used for You Were Meant for Me
# Plot is used for Patti Cake$
# Plot is used for A Letter for Evie
# Plot is used for The Lost World
# Plot is used for Rafter Romance
# Plot is used for Ramona
# Plot is used for The Comedian
# Plot is used for The Shocking Miss Pilgrim
# Plot is used for Blackout
# Plot is used for Touch and Go
# Plot is used for Under New Management
# Plot is used for Take Away
# Plot is used for Subdivision
# Plot is used for Plain Clothes
# Plot is used for Popcorn
# Plot is used for The Night Before
# Plot is used for Once a Thief
# Plot is used for The In Crowd
# Plot is used for Knots
# Plot is used for The Last Man on Earth
# Plot is used for Demolition University
# Plot is used for A
# Plot is used for The Terror of Tiny Town
# Plot is used for Survivor
# Plot is used for Beatriz at Dinner
# Plot is used for The Black Room
# Plot is used for Bangkok Hilton
# Plot is used for Casper: A Spirited Beginning
# Plot is used for Despicable Me 3
# Plot is used for Rock Dog
# Plot is used for Bayou
# Plot is used for The Levelling
# Plot is used for Andersonville
# Plot is used for More Than a Secretary
# Plot is used for Paris Can Wait
# Plot is used for Caravaggio
# Plot is used for The Black Hole
# Plot is used for Idiot
# Plot is used for The Day of the Triffids
# Plot is used for Willie Dynamite
# Plot is used for Donald in Mathmagic Land
# Plot is used for The Tune
# Plot is used for Irene
# Plot is used for Jungle Goddess
# Plot is used for Lost Continent
# Plot is used for The Hellcats
# Plot is used for Daddy-O
# Plot is used for The Amazing Colossal Man
# Plot is used for The Rebel Set
# Plot is used for The Human Duplicators
# Plot is used for Radar Secret Service
# Plot is used for Girls Town
# Plot is used for Bloodlust!
# Plot is used for The Skydivers
# Plot is used for Kitten with a Whip
# Plot is used for The Brute Man
# Plot is used for The Thing That Couldn't Die
# Plot is used for Terror from the Year 5000
# Plot is used for The She-Creature
# Plot is used for I Was a Teenage Werewolf
# Plot is used for Agent for H.A.R.M.
# Plot is used for The Horror of Party Beach
# Plot is used for The Projected Man
# Plot is used for Werewolf
# Plot is used for The Touch of Satan
# Plot is used for Gorgo
# Plot is used for Soultaker
# Plot is used for Merlin's Shop of Mystical Wonders
# Plot is used for Track of the Moon Beast
# Plot is used for The Bad Batch
# Plot is used for War for the Planet of the Apes
# Plot is used for Sophie and the Rising Sun
# Plot is used for Kidnap
# Plot is used for Never So Few
# Plot is used for War Machine
# Plot is used for The Prisoner of Second Avenue
# Plot is used for Wakefield
# Plot is used for Valerian and the City of a Thousand Planets
# Plot is used for The Pass
# Plot is used for Home of the Brave
# Plot is used for Radiant City
# Plot is used for Fedora
# Plot is used for The Magic Roundabout
# Plot is used for Black Butterfly
# Plot is used for Girls Nite Out
# Plot is used for Home Sweet Home
# Plot is used for Nemesis
# Plot is used for Gamer
# Plot is used for She
# Plot is used for The Tracker
# Plot is used for Thunder Road
# Plot is used for Anna Karenina
# Plot is used for Macbeth
# Plot is used for The Journey
# Plot is used for Tiger Shark
# Plot is used for Fanaa
# Plot is used for Tourist Trap
# Plot is used for Growing Up Smith
# Plot is used for That Thing Called Tadhana
# Plot is used for Gulliver's Travels
# Plot is used for Malcolm X
# Plot is used for The Tamarind Seed
# Plot is used for The Wearing of the Grin
# Plot is used for Bunker Hill Bunny
# Plot is used for Ali Baba Bunny
# Plot is used for Shree 420
# Plot is used for Moving Day
# Plot is used for No Smoking
# Plot is used for The Exception
# Plot is used for Out of Time
# Plot is used for Goon: Last of the Enforcers
# Plot is used for Dunkirk
# Plot is used for Feed the Kitty
# Plot is used for Hurdy-Gurdy Hare
# Plot is used for Operation: Rabbit
# Plot is used for Bugs Bunny and the Three Bears
# Plot is used for Devil May Hare
# Plot is used for Gymkata
# Plot is used for A Little Princess
# Plot is used for The Delicious Little Devil
# Plot is used for Heidi
# Plot is used for Hollywood
# Plot is used for Altitude
# Plot is used for Bedevil
# Plot is used for Pokémon 3: The Movie
# Plot is used for Transformers: The Last Knight
# Plot is used for Yolki 3
# Plot is used for Churchill
# Plot is used for Tubelight
# Plot is used for Home
# Plot is used for Australian Rules
# Plot is used for You and Your Stupid Mate
# Plot is used for Island of Lost Women
# Plot is used for Good Time
# Plot is used for Encore
# Plot is used for The House
# Plot is used for Five Came Back
# Plot is used for Necromancy
# Plot is used for Up There
# Plot is used for Jane Eyre
# Plot is used for The Virginian
# Plot is used for 2:22
# Plot is used for Loverboy
# Plot is used for Beat
# Plot is used for All the Wrong Reasons
# Plot is used for City of Ghosts
# Plot is used for The Dark Tower
# Plot is used for Annie
# Plot is used for Inconceivable
# Plot is used for Snow White
# Plot is used for Rumba
# Plot is used for Dirty Dancing
# Plot is used for Bird on a Wire
# Plot is used for Elegy
# Plot is used for Abduction
# Plot is used for Get Out
# Plot is used for The Black Hole
# Plot is used for Nocturne
# Plot is used for The Emoji Movie
# Plot is used for Wolfman
# Plot is used for The Saint
# Plot is used for Collaborator
# Plot is used for The Million Pound Note
# Plot is used for The Hippopotamus
# Plot is used for Aiyyaa
# Plot is used for Wind River
# Plot is used for They're a Weird Mob
# Plot is used for Ratchagan
# Plot is used for Wish Upon
# Plot is used for Girls Trip
# Plot is used for Detroit
# Plot is used for Feed
# Plot is used for Julia Misbehaves
# Plot is used for Sahara
# Plot is used for Muthu
# Plot is used for First Kill
# Plot is used for Lou
# Plot is used for Final Justice
# Plot is used for Terminus
# Plot is used for Love
# Plot is used for Megaville
# Plot is used for Nude on the Moon
# Plot is used for House of the Long Shadows
# Plot is used for Frankenstein Created Woman
# Plot is used for Follow That Camel
# Plot is used for Carry On Camping
# Plot is used for Up 'n' Under
# Plot is used for The Return of Captain Invincible
# Plot is used for That Riviera Touch
# Plot is used for The Pope Must Die
# Plot is used for Carry On England
# Plot is used for A Death in the Gunj
# Plot is used for Dikari
# Plot is used for The Hunters
# Plot is used for Arabian Nights
# Plot is used for Maa
# Plot is used for The Morning After
# Plot is used for House of Horrors
# Plot is used for Robin Hood
# Plot is used for Betrayal

# %%
with open('./movie_lens_overview_with_plots_distilbert_vecs.npy', 'rb') as f:
    word_vecs = np.load(f, allow_pickle=True)

# %%
insert_movie_feature_vectors(word_vecs)

# %%
recommend_for_all_metrics("The Matrix")
# Out:
# vector shape:768
# ['Metropolis', 'Metropolis', 'Android Cop', 'I, Robot', 'Clockstoppers', 'Clockstoppers', 'Death Machine', 'The Terminator', 'They Live', 'The Matrix Revolutions']
# vector shape:768
# ['Suicide Squad', 'Batman', 'Batman', 'Moonraker', 'X-Men: Days of Future Past', 'Star Trek: Insurrection', 'Captain America: The Winter Soldier', 'Star Trek III: The Search for Spock', 'Cyborg X', 'Batman: Mystery of the Batwoman']
# vector shape:768
# ['Flash Gordon', 'Resident Evil: The Final Chapter', 'Prince of Darkness', 'Sleeper', 'Minority Report', 'Terminator 2: Judgment Day', 'Hellraiser: Bloodline', 'Resident Evil: Retribution', 'The Matrix Revolutions', 'The Terminator']
# vector shape:768
# ['Duck Amuck', 'Paranormal Whacktivity', 'Promoción Fantasma', 'Foxtrot', 'Die Farbe', 'The Prospects', 'Festival', 'Ōgon Bat', 'Comedy Central Roast of Pamela Anderson', 'Toy Story']
# vector shape:768
# ['Ganes', 'Бой с Тенью', 'Метель', 'Дура', 'Наша Russia: Яйца судьбы', 'Ι-4: Λούφα Και Απαλλαγή', 'V Boy Idut Odni Stariki', 'Про любоff', 'Kalteva Torni', 'На семи ветрах']
# vector shape:768
# ['Flash Gordon', 'Resident Evil: The Final Chapter', 'Prince of Darkness', 'Sleeper', 'Minority Report', 'Terminator 2: Judgment Day', 'Hellraiser: Bloodline', 'Resident Evil: Retribution', 'The Matrix Revolutions', 'The Terminator']
# vector shape:768
# ['Koroli i kapusta', 'صراع في الوادي', 'Kristin Lavransdatter', 'മുംബൈ പോലീസ്', 'Endurance', 'Ι-4: Λούφα Και Απαλλαγή', 'Il segno di Venere', 'พี่ชาย', 'Le mouton à cinq pattes', 'V Boy Idut Odni Stariki']

# %%
recommend_for_all_metrics("Whiplash")
# Out:
# vector shape:768
# ['Gladiator', 'The Boss', 'The Boss', 'Gun Crazy', 'Redbelt', 'DodgeBall: A True Underdog Story', 'The Lone Wolf Spy Hunt', 'None But the Lonely Heart', 'Whiplash', 'Whiplash']
# vector shape:768
# ['Sat sau ji wong', 'French Roast', 'Tokyo Joe', 'Modern Problems', 'Une Chambre en Ville', 'The Con', "The Man Who Wasn't There", "The Man Who Wasn't There", 'Sonny Boy', 'Save the Date']
# vector shape:768
# ['DodgeBall: A True Underdog Story', 'The Boss', 'The Boss', 'The Big Night', 'Any Which Way You Can', 'They Made Me a Criminal', 'The Prizefighter and the Lady', 'Gladiator', 'Whiplash', 'Whiplash']
# vector shape:768
# ['Foxtrot', 'Die Farbe', 'The Prospects', 'Festival', 'Ōgon Bat', 'Toy Story', 'My Little Eye', 'Touch', 'Whiplash', 'Whiplash']
# vector shape:768
# ['Дура', 'Kalteva Torni', 'Passage de Venus', 'Про любоff', 'Batman: Gotham Knight', 'Buffalo Running', 'На семи ветрах', 'Ι-4: Λούφα Και Απαλλαγή', 'Downeast', 'Koroli i kapusta']
# vector shape:768
# ['DodgeBall: A True Underdog Story', 'The Boss', 'The Boss', 'The Big Night', 'Any Which Way You Can', 'They Made Me a Criminal', 'The Prizefighter and the Lady', 'Gladiator', 'Whiplash', 'Whiplash']
# vector shape:768
# ['พี่ชาย', 'V Boy Idut Odni Stariki', 'മുംബൈ പോലീസ്', 'La vieille qui marchait dans la mer', 'Magnificat', 'Ι-4: Λούφα Και Απαλλαγή', 'Kristin Lavransdatter', 'Endurance', 'Il segno di Venere', 'Le mouton à cinq pattes']

# %%
recommend_for_all_metrics("Toy Story")
# Out:
# vector shape:768
# ['Looney Tunes: Back in Action', 'The Adventures of Elmo in Grouchland', "We're Back! A Dinosaur's Story", 'TerrorVision', 'The Care Bears Movie', 'Once Upon a Forest', 'Casper Meets Wendy', 'Elf', 'Toy Story 2', 'Toy Story 3']
# vector shape:768
# ['Big Hero 6', 'Winnie the Pooh', 'Robots', 'Superman IV: The Quest for Peace', 'Batman', 'Batman', 'Batman Forever', 'Pinocchio', 'Pinocchio', 'Pinocchio']
# vector shape:768
# ['Frankenweenie', 'The Jetsons Meet the Flintstones', 'The Angry Birds Movie', 'Jimmy Neutron: Boy Genius', 'Runaway Brain', 'The Adventures of Elmo in Grouchland', 'TerrorVision', 'Elf', 'Toy Story 2', 'Toy Story 3']
# vector shape:768
# ['5 Flights Up', 'Duck Amuck', 'Promoción Fantasma', 'Foxtrot', 'Die Farbe', 'The Prospects', 'Festival', 'Ōgon Bat', 'Comedy Central Roast of Pamela Anderson', 'The Wrong Road']
# vector shape:768
# ['Sunes sommar', 'Io, Emmanuelle', 'Stiller Sturm', 'Семь кабинок', "Les fragments d'Antonin", 'Кентервильское привидение', 'Diario de un skin', 'Kalteva Torni', 'Ι-4: Λούφα Και Απαλλαγή', 'Endurance']
# vector shape:768
# ['Frankenweenie', 'The Jetsons Meet the Flintstones', 'The Angry Birds Movie', 'Jimmy Neutron: Boy Genius', 'Runaway Brain', 'The Adventures of Elmo in Grouchland', 'TerrorVision', 'Elf', 'Toy Story 2', 'Toy Story 3']
# vector shape:768
# ['Squadra antitruffa', 'Marie-Jo et ses deux amours', 'Metsän Tarina', 'Ι-4: Λούφα Και Απαλλαγή', 'Bad', 'La vieille qui marchait dans la mer', 'Magnificat', 'Endurance', 'Kristin Lavransdatter', 'Il segno di Venere']

# %%
generate_movie_docs_with_plots_vectors_from_distilbert(mix_overview_and_plot=True,
                                                       save_name="movie_lens_overview_with_plots_mixed_distilbert_vecs.npy")
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=45466.0), HTML(value='')))

# %%
with open('./movie_lens_overview_with_plots_mixed_distilbert_vecs.npy', 'rb') as f:
    word_vecs = np.load(f, allow_pickle=True)

# %%
insert_movie_feature_vectors(word_vecs)

# %%
recommend_for_all_metrics("The Matrix")
# Out:
# vector shape:768
# ['ARQ', '屍者の帝国', 'Antiviral', 'Garm Wars: The Last Druid', 'Starchaser: The Legend of Orin', 'Lockout', 'Prometheus', 'The Dark Knight', 'Interstellar', '9']
# vector shape:768
# ['Transformers Prime Beast Hunters: Predacons Rising', 'Sand Castle', 'Sons of Liberty', 'Trancers 3: Deth Lives', 'Star Wars: The Force Awakens', 'The X Files', 'アベンジャーズ コンフィデンシャル：ブラック・ウィドウ ＆ パニッシャー', 'The Matrix', 'Scavengers', 'Batman: Mystery of the Batwoman']
# vector shape:768
# ['The Terminator', 'Predestination', 'Resident Evil: Apocalypse', 'Babylon A.D.', 'Supernova', 'Garm Wars: The Last Druid', 'Starship Troopers', 'Men in Black', 'Lockout', 'Surrogates']
# vector shape:768
# ['Duck Amuck', 'Paranormal Whacktivity', 'Promoción Fantasma', 'Foxtrot', 'Die Farbe', 'The Prospects', 'Festival', 'Ōgon Bat', 'Comedy Central Roast of Pamela Anderson', 'Toy Story']
# vector shape:768
# ['Сатисфакция', 'Бабло', 'Kalteva Torni', 'Бой с Тенью', 'Дура', 'Наша Russia: Яйца судьбы', 'Ι-4: Λούφα Και Απαλλαγή', 'Про любоff', 'V Boy Idut Odni Stariki', 'На семи ветрах']
# vector shape:768
# ['The Terminator', 'Predestination', 'Resident Evil: Apocalypse', 'Babylon A.D.', 'Supernova', 'Garm Wars: The Last Druid', 'Starship Troopers', 'Men in Black', 'Lockout', 'Surrogates']
# vector shape:768
# ['Endurance', 'Le mouton à cinq pattes', 'Il segno di Venere', 'Koroli i kapusta', 'Горько!', 'صراع في الوادي', 'Ι-4: Λούφα Και Απαλλαγή', 'മുംബൈ പോലീസ്', 'พี่ชาย', 'V Boy Idut Odni Stariki']

# %%
recommend_for_all_metrics("Whiplash")
# Out:
# vector shape:768
# ['The Girl Next Door', 'Stardust', 'Up in Smoke', "Child's Play", 'Young Man with a Horn', 'The Gambler', 'The Prizefighter and the Lady', 'Wolf', 'The Recruiter', 'Magnificent Obsession']
# vector shape:768
# ['High Art', 'French Roast', 'Save the Date', 'Un petit boulot', 'The Con', 'Hamnstad', 'Sat sau ji wong', 'Len and Company', 'Sonny Boy', 'Heaven Knows What']
# vector shape:768
# ['Purple Rain', 'School of Rock', 'Whiplash', 'Weary River', 'Body and Soul', 'The Derby Stallion', 'Wild Guitar', 'Wolf', 'Body and Soul', 'Young Man with a Horn']
# vector shape:768
# ['Promoción Fantasma', 'Foxtrot', 'Die Farbe', 'The Prospects', 'Festival', 'Ōgon Bat', 'Donnie Brasco', "The Great St. Trinian's Train Robbery", 'Cheyenne Autumn', 'Carson City']
# vector shape:768
# ['Salut cousin !', 'Downeast', 'Бой с Тенью', 'Наша Russia: Яйца судьбы', 'Дура', 'Ι-4: Λούφα Και Απαλλαγή', 'Про любоff', 'Kalteva Torni', 'На семи ветрах', 'Bad']
# vector shape:768
# ['Purple Rain', 'School of Rock', 'Whiplash', 'Weary River', 'Body and Soul', 'The Derby Stallion', 'Wild Guitar', 'Wolf', 'Body and Soul', 'Young Man with a Horn']
# vector shape:768
# ['V Boy Idut Odni Stariki', 'മുംബൈ പോലീസ്', 'Bad', 'La vieille qui marchait dans la mer', 'Ι-4: Λούφα Και Απαλλαγή', 'Endurance', 'Magnificat', 'Metsän Tarina', 'Kristin Lavransdatter', 'Il segno di Venere']

# %%
recommend_for_all_metrics("Toy Story")
# Out:
# vector shape:768
# ["Charlotte's Web", "Charlotte's Web", "Now You See Him, Now You Don't", 'Frankenweenie', 'Soup to Nuts', 'Oliver & Company', 'The Peanuts Movie', 'Trick or Treat', 'Toy Story 3', 'Toy Story 2']
# vector shape:768
# ['Leaves of Grass', 'Cyborg X', 'Muppets Most Wanted', 'Batman & Mr. Freeze: SubZero', 'Monster High', 'Freaked', 'Batman', "Garfield's Halloween Adventure", 'Ein Freund von mir', 'The X Files']
# vector shape:768
# ['Fred Claus', 'Frankenweenie', 'Elf', 'Snoopy, Come Home', 'Dino Time', 'Frankenweenie', 'Stuart Little 2', 'Runaway Brain', 'Toy Story 3', 'Toy Story 2']
# vector shape:768
# ['5 Flights Up', 'Duck Amuck', 'Promoción Fantasma', 'Foxtrot', 'Die Farbe', 'The Prospects', 'Festival', 'Ōgon Bat', 'Comedy Central Roast of Pamela Anderson', 'Oh, God! You Devil']
# vector shape:768
# ['Lille Fridolf Och Jag', 'A Wake in Providence', 'Frau Müller muss weg!', 'A Lovasíjász', 'Путь к себе', '¡Asu Mare! 2', 'Buffalo Running', 'Ι-4: Λούφα Και Απαλλαγή', 'Kalteva Torni', 'Endurance']
# vector shape:768
# ['Fred Claus', 'Frankenweenie', 'Elf', 'Snoopy, Come Home', 'Dino Time', 'Frankenweenie', 'Stuart Little 2', 'Runaway Brain', 'Toy Story 3', 'Toy Story 2']
# vector shape:768
# ['Marie-Jo et ses deux amours', 'Huis clos', 'Ι-4: Λούφα Και Απαλλαγή', 'Bad', 'Metsän Tarina', 'La vieille qui marchait dans la mer', 'Magnificat', 'Endurance', 'Kristin Lavransdatter', 'Il segno di Venere']

# %%
recommend_for_all_metrics("Forrest Gump")
# Out:
# vector shape:768
# ['Swimming Upstream', 'The Stranger', 'The Raven', 'A Family Thing', 'September 30, 1955', 'Saint Ralph', 'Fallen', 'Unbreakable', 'All My Sons', 'Seabiscuit']
# vector shape:768
# ['The Most Dangerous Man in America: Daniel Ellsberg and the Pentagon Papers', 'Far Out Man', 'The Con', 'David and Bathsheba', 'Winter Meeting', 'Man Down', 'Liliomfi', 'The Clown and The Kid', 'Heaven Knows What', 'The World Made Straight']
# vector shape:768
# ['Harvie Krumpet', 'All My Sons', "It's a Dog's Life", 'Sergeant York', 'Malcolm X', 'The Long Gray Line', 'Little Boy', 'My Dog Skip', 'Unbreakable', 'Of Human Hearts']
# vector shape:768
# ['Duck Amuck', 'Promoción Fantasma', 'Foxtrot', 'Die Farbe', 'The Prospects', 'Festival', 'Ōgon Bat', 'Comedy Central Roast of Pamela Anderson', 'Paranormal Whacktivity', 'Toy Story']
# vector shape:768
# ['Two Years at Sea', 'Le Corbeau', 'Justice League vs. Teen Titans', 'The Mayor of Casterbridge', 'Mosquinha', 'Bad', 'На семи ветрах', 'Kalteva Torni', 'Downeast', 'Koroli i kapusta']
# vector shape:768
# ['Harvie Krumpet', 'All My Sons', "It's a Dog's Life", 'Sergeant York', 'Malcolm X', 'The Long Gray Line', 'Little Boy', 'My Dog Skip', 'Unbreakable', 'Of Human Hearts']
# vector shape:768
# ['صراع في الوادي', 'พี่ชาย', 'La vieille qui marchait dans la mer', 'Metsän Tarina', 'Endurance', 'V Boy Idut Odni Stariki', 'മുംബൈ പോലീസ്', 'Magnificat', 'Kristin Lavransdatter', 'Le mouton à cinq pattes']
